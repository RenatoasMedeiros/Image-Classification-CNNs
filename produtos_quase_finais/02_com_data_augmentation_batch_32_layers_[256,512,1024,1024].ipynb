# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
# CONSTANTES
BATCH_SIZE = 32
IMG_SIZE = 32
NUM_CLASSES = 10  # nº classes para identificar
NUM_EPOCHS = 60
LEARNING_RATE = 0.001
DENSE_LAYERS = [256, 512, 1024, 1024]

# %%
# Define directories
train_dirs = ['./dataset/train/train1', './dataset/train/train2', './dataset/train/train3', './dataset/train/train5']
validation_dir = './dataset/validation'
test_dir = './dataset/test'

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    fill_mode='nearest')

validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# training generators
train_generators = [train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical') for train_dir in train_dirs]

# Necessário para junstar os trainning generators


def combined_generator(generators):
    while True:
        for generator in generators:
            yield next(generator)


train_generator = combined_generator(train_generators)

# Validation e test generators
validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical')
# Out:
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.

# %%
from tensorflow.keras import backend as K
from tensorflow.keras.metrics import Metric

class Precision(Metric):
    def __init__(self, name='precision', **kwargs):
        super(Precision, self).__init__(name=name, **kwargs)
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.predicted_positives = self.add_weight(name='pp', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = K.round(y_pred)
        y_true = K.cast(y_true, 'float32')
        self.true_positives.assign_add(K.sum(y_true * y_pred))
        self.predicted_positives.assign_add(K.sum(y_pred))

    def result(self):
        return self.true_positives / (self.predicted_positives + K.epsilon())

    def reset_states(self):
        self.true_positives.assign(0)
        self.predicted_positives.assign(0)

class Recall(Metric):
    def __init__(self, name='recall', **kwargs):
        super(Recall, self).__init__(name=name, **kwargs)
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.actual_positives = self.add_weight(name='ap', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = K.round(y_pred)
        y_true = K.cast(y_true, 'float32')
        self.true_positives.assign_add(K.sum(y_true * y_pred))
        self.actual_positives.assign_add(K.sum(y_true))

    def result(self):
        return self.true_positives / (self.actual_positives + K.epsilon())

    def reset_states(self):
        self.true_positives.assign(0)
        self.actual_positives.assign(0)

class F1Score(Metric):
    def __init__(self, name='f1_score', **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.precision = Precision()
        self.recall = Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred)
        self.recall.update_state(y_true, y_pred)

    def result(self):
        precision = self.precision.result()
        recall = self.recall.result()
        return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

    def reset_states(self):
        self.precision.reset_states()
        self.recall.reset_states()

# %%
model = Sequential([
    Conv2D(DENSE_LAYERS[0], (3, 3), input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.3),
    
    Conv2D(DENSE_LAYERS[1], (3, 3)),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.5),
    
    Conv2D(DENSE_LAYERS[2], (3, 3)),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.5),
    
    Flatten(),
    Dense(DENSE_LAYERS[3]),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),
    
    Dense(NUM_CLASSES, activation='softmax')
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=LEARNING_RATE),
              loss='categorical_crossentropy',
              metrics=['accuracy', Precision(), Recall(), F1Score()])


model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 30, 30, 128)       3584
#
#  batch_normalization_4 (Batc  (None, 30, 30, 128)      512
#  hNormalization)
#
#  activation_4 (Activation)   (None, 30, 30, 128)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 15, 15, 128)      0
#  2D)
#
#  dropout_4 (Dropout)         (None, 15, 15, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 13, 13, 256)       295168
#
#  batch_normalization_5 (Batc  (None, 13, 13, 256)      1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 13, 13, 256)       0
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  dropout_5 (Dropout)         (None, 6, 6, 256)         0
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 512)         1180160
#
#  batch_normalization_6 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_6 (Activation)   (None, 4, 4, 512)         0
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  dropout_6 (Dropout)         (None, 2, 2, 512)         0
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 512)               1049088
#
#  batch_normalization_7 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation_7 (Activation)   (None, 512)               0
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 2,538,762
# Trainable params: 2,535,946
# Non-trainable params: 2,816
# _________________________________________________________________

# %%
# Definir os Callbacks

# Para salvar o melhor modelo com base na acurácia de validação
checkpoint = ModelCheckpoint("models/02_com_data_augmentation_batch_size_32_layers_[256, 512, 1024, 1024].keras", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# Parar o treinamento se não houver melhoria na loss após x epochs
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Salvar para csv
csv_logger = CSVLogger(f'logs/02_com_data_augmentation_batch_size_{BATCH_SIZE}_image_size_{IMG_SIZE}_layers_{DENSE_LAYERS}.csv', append=True)

# Reduzir a learning rate se não houver melhoria na loss após x epochs (lembrar de deixar este valor sempre menor que a patience no early_stopping!!)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)

# %%
# Calculate steps per epoch
steps_per_epoch = sum([gen.samples // BATCH_SIZE for gen in train_generators])

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=NUM_EPOCHS,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // BATCH_SIZE,
    callbacks=[checkpoint, early_stopping, csv_logger, reduce_lr]
)

# Evaluate the model
# Evaluate the model
results = model.evaluate(test_generator)
loss, accuracy, precision, recall, f1_score = results[:5]
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
print(f"Test Precision: {precision}")
print(f"Test Recall: {recall}")
print(f"Test F1 Score: {f1_score}")
# Out:
# Epoch 1/30
# 1248/1248 [==============================] - ETA: 0s - loss: 2.0582 - accuracy: 0.2720 - precision: 0.3781 - recall: 0.0682 - f1_score: 0.1155
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric Precision implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric Recall implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# Epoch 1: val_accuracy improved from -inf to 0.34645, saving model to models\02_com_data_augmentation.keras
# 1248/1248 [==============================] - 45s 36ms/step - loss: 2.0582 - accuracy: 0.2720 - precision: 0.3781 - recall: 0.0682 - f1_score: 0.1155 - val_loss: 1.7326 - val_accuracy: 0.3465 - val_precision: 0.5025 - val_recall: 0.1525 - val_f1_score: 0.2340 - lr: 0.0010
# Epoch 2/30
# 1248/1248 [==============================] - ETA: 0s - loss: 1.7917 - accuracy: 0.3471 - precision: 0.5371 - recall: 0.1045 - f1_score: 0.1750
# Epoch 2: val_accuracy improved from 0.34645 to 0.37049, saving model to models\02_com_data_augmentation.keras
# 1248/1248 [==============================] - 38s 30ms/step - loss: 1.7917 - accuracy: 0.3471 - precision: 0.5371 - recall: 0.1045 - f1_score: 0.1750 - val_loss: 1.8164 - val_accuracy: 0.3705 - val_precision: 0.4969 - val_recall: 0.2484 - val_f1_score: 0.3312 - lr: 0.0010
# Epoch 3/30
# 1248/1248 [==============================] - ETA: 0s - loss: 1.7029 - accuracy: 0.3812 - precision: 0.5743 - recall: 0.1378 - f1_score: 0.2223
# Epoch 3: val_accuracy improved from 0.37049 to 0.46394, saving model to models\02_com_data_augmentation.keras
# 1248/1248 [==============================] - 37s 30ms/step - loss: 1.7029 - accuracy: 0.3812 - precision: 0.5743 - recall: 0.1378 - f1_score: 0.2223 - val_loss: 1.4577 - val_accuracy: 0.4639 - val_precision: 0.6542 - val_recall: 0.2843 - val_f1_score: 0.3963 - lr: 0.0010
# Epoch 4/30
# 1247/1248 [============================>.] - ETA: 0s - loss: 1.6413 - accuracy: 0.4041 - precision: 0.6032 - recall: 0.1664 - f1_score: 0.2609
# Epoch 4: val_accuracy did not improve from 0.46394
# 1248/1248 [==============================] - 37s 30ms/step - loss: 1.6413 - accuracy: 0.4041 - precision: 0.6032 - recall: 0.1665 - f1_score: 0.2609 - val_loss: 1.5709 - val_accuracy: 0.4303 - val_precision: 0.5509 - val_recall: 0.3148 - val_f1_score: 0.4007 - lr: 0.0010
# Epoch 5/30
# 1247/1248 [============================>.] - ETA: 0s - loss: 1.5968 - accuracy: 0.4242 - precision: 0.6238 - recall: 0.1918 - f1_score: 0.2934
# Epoch 5: val_accuracy did not improve from 0.46394
# 1248/1248 [==============================] - 37s 30ms/step - loss: 1.5968 - accuracy: 0.4242 - precision: 0.6238 - recall: 0.1918 - f1_score: 0.2934 - val_loss: 1.4983 - val_accuracy: 0.4505 - val_precision: 0.5978 - val_recall: 0.3217 - val_f1_score: 0.4183 - lr: 0.0010
# Epoch 6/30
# 1247/1248 [============================>.] - ETA: 0s - loss: 1.5518 - accuracy: 0.4392 - precision: 0.6388 - recall: 0.2141 - f1_score: 0.3207
# Epoch 6: val_accuracy did not improve from 0.46394
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1248/1248 [==============================] - 37s 29ms/step - loss: 1.5517 - accuracy: 0.4393 - precision: 0.6389 - recall: 0.2141 - f1_score: 0.3208 - val_loss: 1.5706 - val_accuracy: 0.4483 - val_precision: 0.5765 - val_recall: 0.3446 - val_f1_score: 0.4313 - lr: 0.0010
# Epoch 7/30
# 1247/1248 [============================>.] - ETA: 0s - loss: 1.4973 - accuracy: 0.4644 - precision: 0.6593 - recall: 0.2382 - f1_score: 0.3499
# Epoch 7: val_accuracy improved from 0.46394 to 0.56290, saving model to models\02_com_data_augmentation.keras
# 1248/1248 [==============================] - 37s 29ms/step - loss: 1.4972 - accuracy: 0.4643 - precision: 0.6593 - recall: 0.2381 - f1_score: 0.3499 - val_loss: 1.2213 - val_accuracy: 0.5629 - val_precision: 0.7003 - val_recall: 0.4076 - val_f1_score: 0.5153 - lr: 5.0000e-04
# Epoch 8/30
# 1248/1248 [==============================] - ETA: 0s - loss: 1.4625 - accuracy: 0.4792 - precision: 0.6699 - recall: 0.2601 - f1_score: 0.3747
# Epoch 8: val_accuracy did not improve from 0.56290
# 1248/1248 [==============================] - 37s 29ms/step - loss: 1.4625 - accuracy: 0.4792 - precision: 0.6699 - recall: 0.2601 - f1_score: 0.3747 - val_loss: 1.2224 - val_accuracy: 0.5615 - val_precision: 0.7210 - val_recall: 0.4387 - val_f1_score: 0.5455 - lr: 5.0000e-04
# Epoch 9/30
# 1248/1248 [==============================] - ETA: 0s - loss: 1.4385 - accuracy: 0.4852 - precision: 0.6747 - recall: 0.2730 - f1_score: 0.3888
# Epoch 9: val_accuracy improved from 0.56290 to 0.60597, saving model to models\02_com_data_augmentation.keras
# 1248/1248 [==============================] - 37s 30ms/step - loss: 1.4385 - accuracy: 0.4852 - precision: 0.6747 - recall: 0.2730 - f1_score: 0.3888 - val_loss: 1.0988 - val_accuracy: 0.6060 - val_precision: 0.7746 - val_recall: 0.4450 - val_f1_score: 0.5653 - lr: 5.0000e-04
# Epoch 10/30
# 1247/1248 [============================>.] - ETA: 0s - loss: 1.4231 - accuracy: 0.4913 - precision: 0.6863 - recall: 0.2826 - f1_score: 0.4003
# Epoch 10: val_accuracy did not improve from 0.60597
# 1248/1248 [==============================] - 37s 29ms/step - loss: 1.4231 - accuracy: 0.4913 - precision: 0.6861 - recall: 0.2825 - f1_score: 0.4002 - val_loss: 1.4461 - val_accuracy: 0.4871 - val_precision: 0.5850 - val_recall: 0.3905 - val_f1_score: 0.4684 - lr: 5.0000e-04
# Epoch 11/30
# 1248/1248 [==============================] - ETA: 0s - loss: 1.4077 - accuracy: 0.5000 - precision: 0.6843 - recall: 0.2923 - f1_score: 0.4096
# Epoch 11: val_accuracy did not improve from 0.60597
# 1248/1248 [==============================] - 37s 29ms/step - loss: 1.4077 - accuracy: 0.5000 - precision: 0.6843 - recall: 0.2923 - f1_score: 0.4096 - val_loss: 1.3637 - val_accuracy: 0.5346 - val_precision: 0.6558 - val_recall: 0.4466 - val_f1_score: 0.5314 - lr: 5.0000e-04
# Epoch 12/30
# 1247/1248 [============================>.] - ETA: 0s - loss: 1.3912 - accuracy: 0.5034 - precision: 0.6868 - recall: 0.2980 - f1_score: 0.4157
# Epoch 12: val_accuracy did not improve from 0.60597
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1248/1248 [==============================] - 36s 29ms/step - loss: 1.3911 - accuracy: 0.5034 - precision: 0.6867 - recall: 0.2980 - f1_score: 0.4157 - val_loss: 1.4743 - val_accuracy: 0.4874 - val_precision: 0.5757 - val_recall: 0.3837 - val_f1_score: 0.4605 - lr: 5.0000e-04
# Epoch 13/30
# 1248/1248 [==============================] - ETA: 0s - loss: 1.3626 - accuracy: 0.5152 - precision: 0.7011 - recall: 0.3154 - f1_score: 0.4351
# Epoch 13: val_accuracy improved from 0.60597 to 0.63081, saving model to models\02_com_data_augmentation.keras
# 1248/1248 [==============================] - 36s 29ms/step - loss: 1.3626 - accuracy: 0.5152 - precision: 0.7011 - recall: 0.3154 - f1_score: 0.4351 - val_loss: 1.0448 - val_accuracy: 0.6308 - val_precision: 0.7873 - val_recall: 0.4771 - val_f1_score: 0.5941 - lr: 2.5000e-04
# Epoch 14/30
# 1248/1248 [==============================] - ETA: 0s - loss: 1.3521 - accuracy: 0.5215 - precision: 0.7003 - recall: 0.3224 - f1_score: 0.4415
# Epoch 14: val_accuracy did not improve from 0.63081
# 1248/1248 [==============================] - 36s 29ms/step - loss: 1.3521 - accuracy: 0.5215 - precision: 0.7003 - recall: 0.3224 - f1_score: 0.4415 - val_loss: 1.0910 - val_accuracy: 0.6107 - val_precision: 0.7379 - val_recall: 0.4914 - val_f1_score: 0.5899 - lr: 2.5000e-04
# Epoch 15/30
# 1248/1248 [==============================] - ETA: 0s - loss: 1.3386 - accuracy: 0.5214 - precision: 0.6963 - recall: 0.3265 - f1_score: 0.4446
# Epoch 15: val_accuracy did not improve from 0.63081
# 1248/1248 [==============================] - 36s 29ms/step - loss: 1.3386 - accuracy: 0.5214 - precision: 0.6963 - recall: 0.3265 - f1_score: 0.4446 - val_loss: 1.0804 - val_accuracy: 0.6079 - val_precision: 0.7256 - val_recall: 0.4899 - val_f1_score: 0.5849 - lr: 2.5000e-04
# Epoch 16/30
# 1247/1248 [============================>.] - ETA: 0s - loss: 1.3384 - accuracy: 0.5231 - precision: 0.7002 - recall: 0.3294 - f1_score: 0.4480
# Epoch 16: val_accuracy did not improve from 0.63081
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1248/1248 [==============================] - 36s 29ms/step - loss: 1.3386 - accuracy: 0.5230 - precision: 0.7001 - recall: 0.3294 - f1_score: 0.4480 - val_loss: 1.0907 - val_accuracy: 0.6056 - val_precision: 0.7170 - val_recall: 0.4841 - val_f1_score: 0.5779 - lr: 2.5000e-04
# Epoch 17/30
# 1248/1248 [==============================] - ETA: 0s - loss: 1.3106 - accuracy: 0.5345 - precision: 0.7120 - recall: 0.3394 - f1_score: 0.4597
# Epoch 17: val_accuracy did not improve from 0.63081
# 1248/1248 [==============================] - 37s 29ms/step - loss: 1.3106 - accuracy: 0.5345 - precision: 0.7120 - recall: 0.3394 - f1_score: 0.4597 - val_loss: 1.0927 - val_accuracy: 0.6087 - val_precision: 0.7241 - val_recall: 0.5005 - val_f1_score: 0.5919 - lr: 1.2500e-04
# Epoch 18/30
# 1248/1248 [==============================] - ETA: 0s - loss: 1.3038 - accuracy: 0.5358 - precision: 0.7142 - recall: 0.3499 - f1_score: 0.4697
# Epoch 18: val_accuracy improved from 0.63081 to 0.64884, saving model to models\02_com_data_augmentation.keras
# 1248/1248 [==============================] - 37s 30ms/step - loss: 1.3038 - accuracy: 0.5358 - precision: 0.7142 - recall: 0.3499 - f1_score: 0.4697 - val_loss: 0.9818 - val_accuracy: 0.6488 - val_precision: 0.7731 - val_recall: 0.5309 - val_f1_score: 0.6295 - lr: 1.2500e-04
# Epoch 19/30
# 1248/1248 [==============================] - ETA: 0s - loss: 1.2984 - accuracy: 0.5402 - precision: 0.7156 - recall: 0.3470 - f1_score: 0.4673
# Epoch 19: val_accuracy did not improve from 0.64884
# 1248/1248 [==============================] - 37s 29ms/step - loss: 1.2984 - accuracy: 0.5402 - precision: 0.7156 - recall: 0.3470 - f1_score: 0.4673 - val_loss: 1.2416 - val_accuracy: 0.5630 - val_precision: 0.6443 - val_recall: 0.4674 - val_f1_score: 0.5418 - lr: 1.2500e-04
# Epoch 20/30
# 1247/1248 [============================>.] - ETA: 0s - loss: 1.3056 - accuracy: 0.5360 - precision: 0.7109 - recall: 0.3513 - f1_score: 0.4702
# Epoch 20: val_accuracy did not improve from 0.64884
# 1248/1248 [==============================] - 36s 29ms/step - loss: 1.3056 - accuracy: 0.5360 - precision: 0.7109 - recall: 0.3512 - f1_score: 0.4702 - val_loss: 1.0086 - val_accuracy: 0.6376 - val_precision: 0.7524 - val_recall: 0.5214 - val_f1_score: 0.6160 - lr: 1.2500e-04
# Epoch 21/30
# 1248/1248 [==============================] - ETA: 0s - loss: 1.2884 - accuracy: 0.5444 - precision: 0.7186 - recall: 0.3587 - f1_score: 0.4785
# Epoch 21: val_accuracy improved from 0.64884 to 0.65655, saving model to models\02_com_data_augmentation.keras
# 1248/1248 [==============================] - 37s 29ms/step - loss: 1.2884 - accuracy: 0.5444 - precision: 0.7186 - recall: 0.3587 - f1_score: 0.4785 - val_loss: 0.9552 - val_accuracy: 0.6566 - val_precision: 0.7784 - val_recall: 0.5438 - val_f1_score: 0.6402 - lr: 1.2500e-04
# Epoch 22/30
# 1247/1248 [============================>.] - ETA: 0s - loss: 1.2889 - accuracy: 0.5431 - precision: 0.7137 - recall: 0.3568 - f1_score: 0.4758
# Epoch 22: val_accuracy did not improve from 0.65655
# 1248/1248 [==============================] - 36s 29ms/step - loss: 1.2890 - accuracy: 0.5432 - precision: 0.7135 - recall: 0.3568 - f1_score: 0.4757 - val_loss: 1.0605 - val_accuracy: 0.6175 - val_precision: 0.7321 - val_recall: 0.5072 - val_f1_score: 0.5993 - lr: 1.2500e-04
# Epoch 23/30
# 1248/1248 [==============================] - ETA: 0s - loss: 1.2861 - accuracy: 0.5455 - precision: 0.7168 - recall: 0.3610 - f1_score: 0.4802
# Epoch 23: val_accuracy did not improve from 0.65655
# 1248/1248 [==============================] - 36s 29ms/step - loss: 1.2861 - accuracy: 0.5455 - precision: 0.7168 - recall: 0.3610 - f1_score: 0.4802 - val_loss: 1.0573 - val_accuracy: 0.6164 - val_precision: 0.7257 - val_recall: 0.5122 - val_f1_score: 0.6006 - lr: 1.2500e-04
# Epoch 24/30
# 1248/1248 [==============================] - ETA: 0s - loss: 1.2893 - accuracy: 0.5435 - precision: 0.7147 - recall: 0.3586 - f1_score: 0.4776
# Epoch 24: val_accuracy did not improve from 0.65655
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1248/1248 [==============================] - 36s 29ms/step - loss: 1.2893 - accuracy: 0.5435 - precision: 0.7147 - recall: 0.3586 - f1_score: 0.4776 - val_loss: 1.0120 - val_accuracy: 0.6364 - val_precision: 0.7472 - val_recall: 0.5294 - val_f1_score: 0.6198 - lr: 1.2500e-04
# Epoch 25/30
# 1248/1248 [==============================] - ETA: 0s - loss: 1.2756 - accuracy: 0.5514 - precision: 0.7210 - recall: 0.3676 - f1_score: 0.4869
# Epoch 25: val_accuracy improved from 0.65655 to 0.65855, saving model to models\02_com_data_augmentation.keras
# 1248/1248 [==============================] - 36s 29ms/step - loss: 1.2756 - accuracy: 0.5514 - precision: 0.7210 - recall: 0.3676 - f1_score: 0.4869 - val_loss: 0.9566 - val_accuracy: 0.6586 - val_precision: 0.7691 - val_recall: 0.5467 - val_f1_score: 0.6391 - lr: 6.2500e-05
# Epoch 26/30
# 1247/1248 [============================>.] - ETA: 0s - loss: 1.2650 - accuracy: 0.5504 - precision: 0.7207 - recall: 0.3663 - f1_score: 0.4857
# Epoch 26: val_accuracy did not improve from 0.65855
# 1248/1248 [==============================] - 37s 29ms/step - loss: 1.2647 - accuracy: 0.5506 - precision: 0.7209 - recall: 0.3664 - f1_score: 0.4858 - val_loss: 0.9775 - val_accuracy: 0.6514 - val_precision: 0.7632 - val_recall: 0.5437 - val_f1_score: 0.6350 - lr: 6.2500e-05
# 313/313 [==============================] - 6s 18ms/step - loss: 0.9370 - accuracy: 0.6678 - precision: 0.7780 - recall: 0.5515 - f1_score: 0.6454
# Test Loss: 0.9370151162147522
# Test Accuracy: 0.6678000092506409
# Test Precision: 0.7779658436775208
# Test Recall: 0.5515000224113464
# Test F1 Score: 0.645444393157959

# %%
# Plot training history
plt.figure(figsize=(12, 8))
plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(history.history['val_precision'], label='val_precision')
plt.plot(history.history['val_recall'], label='val_recall')
plt.plot(history.history['val_f1_score'], label='val_f1_score')
plt.xlabel('Epoch')
plt.ylabel('Metrics')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.title('Validation Precision, Recall, F1 Score')

plt.savefig(f'./plots/02_com_data_augmentation.png')
plt.tight_layout()
plt.show()
