# %%
from tensorflow.keras.metrics import Metric
from tensorflow.keras import backend as K
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
# CONSTANTES
BATCH_SIZE = 64
IMG_SIZE = 32
NUM_CLASSES = 10  # nº classes para identificar
NUM_EPOCHS = 100
LEARNING_RATE = 0.001
DENSE_LAYERS = [256, 512, 1024, 1024]

# %%
# Define directories
train_dirs = ['./dataset/train/train1', './dataset/train/train2',
              './dataset/train/train3', './dataset/train/train5']
validation_dir = './dataset/validation'
test_dir = './dataset/test'

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.01,
    height_shift_range=0.01,
    horizontal_flip=True,
    fill_mode='nearest')

validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# training generators
train_generators = [train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical') for train_dir in train_dirs]

# Necessário para junstar os trainning generators


def combined_generator(generators):
    while True:
        for generator in generators:
            yield next(generator)


train_generator = combined_generator(train_generators)

# Validation e test generators
validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical')
# Out:
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.

# %%
class Precision(Metric):
    def __init__(self, name='precision', **kwargs):
        super(Precision, self).__init__(name=name, **kwargs)
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.predicted_positives = self.add_weight(
            name='pp', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = K.round(y_pred)
        y_true = K.cast(y_true, 'float32')
        self.true_positives.assign_add(K.sum(y_true * y_pred))
        self.predicted_positives.assign_add(K.sum(y_pred))

    def result(self):
        return self.true_positives / (self.predicted_positives + K.epsilon())

    def reset_states(self):
        self.true_positives.assign(0)
        self.predicted_positives.assign(0)


class Recall(Metric):
    def __init__(self, name='recall', **kwargs):
        super(Recall, self).__init__(name=name, **kwargs)
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.actual_positives = self.add_weight(name='ap', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = K.round(y_pred)
        y_true = K.cast(y_true, 'float32')
        self.true_positives.assign_add(K.sum(y_true * y_pred))
        self.actual_positives.assign_add(K.sum(y_true))

    def result(self):
        return self.true_positives / (self.actual_positives + K.epsilon())

    def reset_states(self):
        self.true_positives.assign(0)
        self.actual_positives.assign(0)


class F1Score(Metric):
    def __init__(self, name='f1_score', **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.precision = Precision()
        self.recall = Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred)
        self.recall.update_state(y_true, y_pred)

    def result(self):
        precision = self.precision.result()
        recall = self.recall.result()
        return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

    def reset_states(self):
        self.precision.reset_states()
        self.recall.reset_states()

# %%
model = Sequential([
    Conv2D(DENSE_LAYERS[0], (3, 3), input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.3),

    Conv2D(DENSE_LAYERS[1], (3, 3)),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.5),

    Conv2D(DENSE_LAYERS[2], (3, 3)),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.5),

    Flatten(),
    Dense(DENSE_LAYERS[3]),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),

    Dense(NUM_CLASSES, activation='softmax')
])

# Compile the model
model.compile(optimizer=RMSprop(learning_rate=LEARNING_RATE),
              loss='categorical_crossentropy',
              metrics=['accuracy', Precision(), Recall(), F1Score()])


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 256)       7168
#
#  batch_normalization (BatchN  (None, 30, 30, 256)      1024
#  ormalization)
#
#  activation (Activation)     (None, 30, 30, 256)       0
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 256)      0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 256)       0
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 512)       1180160
#
#  batch_normalization_1 (Batc  (None, 13, 13, 512)      2048
#  hNormalization)
#
#  activation_1 (Activation)   (None, 13, 13, 512)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 512)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 512)         0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 1024)        4719616
#
#  batch_normalization_2 (Batc  (None, 4, 4, 1024)       4096
#  hNormalization)
#
#  activation_2 (Activation)   (None, 4, 4, 1024)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 1024)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 1024)        0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 1024)              4195328
#
#  batch_normalization_3 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  activation_3 (Activation)   (None, 1024)              0
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 10,123,786
# Trainable params: 10,118,154
# Non-trainable params: 5,632
# _________________________________________________________________

# %%
# Definir os Callbacks

# Para salvar o melhor modelo com base na acurácia de validação
checkpoint = ModelCheckpoint(
    "models/modelo_S_com_data_augmentation.keras", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# Parar o treinamento se não houver melhoria na loss após x epochs
early_stopping = EarlyStopping(
    monitor='val_loss', patience=10, restore_best_weights=True)

# Salvar para csv
csv_logger = CSVLogger(
    f'logs/modelo_S_com_data_augmentation.csv', append=True)

# Reduzir a learning rate se não houver melhoria na loss após x epochs (lembrar de deixar este valor sempre menor que a patience no early_stopping!!)
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=3, verbose=1)

# %%
# Calculate steps per epoch
steps_per_epoch = sum([gen.samples // BATCH_SIZE for gen in train_generators])

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=NUM_EPOCHS,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // BATCH_SIZE,
    callbacks=[checkpoint, early_stopping, csv_logger, reduce_lr]
)

# Evaluate the model
# Evaluate the model
results = model.evaluate(test_generator)
loss, accuracy, precision, recall, f1_score = results[:5]
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
print(f"Test Precision: {precision}")
print(f"Test Recall: {recall}")
print(f"Test F1 Score: {f1_score}")
# Out:
# Epoch 1/100
# 624/624 [==============================] - ETA: 0s - loss: 1.6755 - accuracy: 0.4364 - precision: 0.5456 - recall: 0.2999 - f1_score: 0.3871
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric Precision implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric Recall implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# Epoch 1: val_accuracy improved from -inf to 0.49509, saving model to models\modelo_S_com_data_augmentation.keras
# 624/624 [==============================] - 67s 89ms/step - loss: 1.6755 - accuracy: 0.4364 - precision: 0.5456 - recall: 0.2999 - f1_score: 0.3871 - val_loss: 1.4864 - val_accuracy: 0.4951 - val_precision: 0.6104 - val_recall: 0.3799 - val_f1_score: 0.4683 - lr: 0.0010
# Epoch 2/100
# 624/624 [==============================] - ETA: 0s - loss: 1.2398 - accuracy: 0.5671 - precision: 0.6893 - recall: 0.4407 - f1_score: 0.5377
# Epoch 2: val_accuracy did not improve from 0.49509
# 624/624 [==============================] - 38s 60ms/step - loss: 1.2398 - accuracy: 0.5671 - precision: 0.6893 - recall: 0.4407 - f1_score: 0.5377 - val_loss: 2.0701 - val_accuracy: 0.3559 - val_precision: 0.5510 - val_recall: 0.2293 - val_f1_score: 0.3238 - lr: 0.0010
# Epoch 3/100
# 624/624 [==============================] - ETA: 0s - loss: 1.0978 - accuracy: 0.6183 - precision: 0.7299 - recall: 0.5035 - f1_score: 0.5959
# Epoch 3: val_accuracy did not improve from 0.49509
# 624/624 [==============================] - 48s 77ms/step - loss: 1.0978 - accuracy: 0.6183 - precision: 0.7299 - recall: 0.5035 - f1_score: 0.5959 - val_loss: 1.6627 - val_accuracy: 0.4887 - val_precision: 0.5492 - val_recall: 0.3925 - val_f1_score: 0.4578 - lr: 0.0010
# Epoch 4/100
# 624/624 [==============================] - ETA: 0s - loss: 1.0238 - accuracy: 0.6452 - precision: 0.7510 - recall: 0.5403 - f1_score: 0.6285
# Epoch 4: val_accuracy improved from 0.49509 to 0.61038, saving model to models\modelo_S_com_data_augmentation.keras
# 624/624 [==============================] - 39s 63ms/step - loss: 1.0238 - accuracy: 0.6452 - precision: 0.7510 - recall: 0.5403 - f1_score: 0.6285 - val_loss: 1.1553 - val_accuracy: 0.6104 - val_precision: 0.7333 - val_recall: 0.5197 - val_f1_score: 0.6083 - lr: 0.0010
# Epoch 5/100
# 624/624 [==============================] - ETA: 0s - loss: 0.9605 - accuracy: 0.6704 - precision: 0.7677 - recall: 0.5696 - f1_score: 0.6539
# Epoch 5: val_accuracy improved from 0.61038 to 0.68470, saving model to models\modelo_S_com_data_augmentation.keras
# 624/624 [==============================] - 36s 57ms/step - loss: 0.9605 - accuracy: 0.6704 - precision: 0.7677 - recall: 0.5696 - f1_score: 0.6539 - val_loss: 0.9224 - val_accuracy: 0.6847 - val_precision: 0.8091 - val_recall: 0.5522 - val_f1_score: 0.6564 - lr: 0.0010
# Epoch 6/100
# 623/624 [============================>.] - ETA: 0s - loss: 0.9304 - accuracy: 0.6798 - precision: 0.7748 - recall: 0.5828 - f1_score: 0.6652
# Epoch 6: val_accuracy improved from 0.68470 to 0.68700, saving model to models\modelo_S_com_data_augmentation.keras
# 624/624 [==============================] - 37s 59ms/step - loss: 0.9300 - accuracy: 0.6800 - precision: 0.7749 - recall: 0.5829 - f1_score: 0.6653 - val_loss: 0.9111 - val_accuracy: 0.6870 - val_precision: 0.8131 - val_recall: 0.5587 - val_f1_score: 0.6623 - lr: 0.0010
# Epoch 7/100
# 624/624 [==============================] - ETA: 0s - loss: 0.9037 - accuracy: 0.6936 - precision: 0.7856 - recall: 0.5977 - f1_score: 0.6789
# Epoch 7: val_accuracy did not improve from 0.68700
# 624/624 [==============================] - 39s 62ms/step - loss: 0.9037 - accuracy: 0.6936 - precision: 0.7856 - recall: 0.5977 - f1_score: 0.6789 - val_loss: 1.5100 - val_accuracy: 0.5057 - val_precision: 0.5907 - val_recall: 0.4043 - val_f1_score: 0.4801 - lr: 0.0010
# Epoch 8/100
# 624/624 [==============================] - ETA: 0s - loss: 0.8821 - accuracy: 0.7032 - precision: 0.7915 - recall: 0.6093 - f1_score: 0.6886
# Epoch 8: val_accuracy did not improve from 0.68700
# 624/624 [==============================] - 35s 56ms/step - loss: 0.8821 - accuracy: 0.7032 - precision: 0.7915 - recall: 0.6093 - f1_score: 0.6886 - val_loss: 1.0914 - val_accuracy: 0.6266 - val_precision: 0.7962 - val_recall: 0.4194 - val_f1_score: 0.5494 - lr: 0.0010
# Epoch 9/100
# 624/624 [==============================] - ETA: 0s - loss: 0.8486 - accuracy: 0.7144 - precision: 0.8004 - recall: 0.6209 - f1_score: 0.6993
# Epoch 9: val_accuracy did not improve from 0.68700
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 624/624 [==============================] - 36s 57ms/step - loss: 0.8486 - accuracy: 0.7144 - precision: 0.8004 - recall: 0.6209 - f1_score: 0.6993 - val_loss: 0.9765 - val_accuracy: 0.6826 - val_precision: 0.8642 - val_recall: 0.5023 - val_f1_score: 0.6353 - lr: 0.0010
# Epoch 10/100
# 623/624 [============================>.] - ETA: 0s - loss: 0.7839 - accuracy: 0.7365 - precision: 0.8180 - recall: 0.6520 - f1_score: 0.7256
# Epoch 10: val_accuracy improved from 0.68700 to 0.73307, saving model to models\modelo_S_com_data_augmentation.keras
# 624/624 [==============================] - 34s 55ms/step - loss: 0.7835 - accuracy: 0.7366 - precision: 0.8180 - recall: 0.6521 - f1_score: 0.7257 - val_loss: 0.8464 - val_accuracy: 0.7331 - val_precision: 0.8872 - val_recall: 0.5336 - val_f1_score: 0.6664 - lr: 5.0000e-04
# Epoch 11/100
# 624/624 [==============================] - ETA: 0s - loss: 0.7572 - accuracy: 0.7474 - precision: 0.8238 - recall: 0.6656 - f1_score: 0.7363
# Epoch 11: val_accuracy did not improve from 0.73307
# 624/624 [==============================] - 36s 58ms/step - loss: 0.7572 - accuracy: 0.7474 - precision: 0.8238 - recall: 0.6656 - f1_score: 0.7363 - val_loss: 0.8744 - val_accuracy: 0.7213 - val_precision: 0.8687 - val_recall: 0.5468 - val_f1_score: 0.6711 - lr: 5.0000e-04
# Epoch 12/100
# 624/624 [==============================] - ETA: 0s - loss: 0.7495 - accuracy: 0.7488 - precision: 0.8238 - recall: 0.6706 - f1_score: 0.7393
# Epoch 12: val_accuracy improved from 0.73307 to 0.75982, saving model to models\modelo_S_com_data_augmentation.keras
# 624/624 [==============================] - 36s 57ms/step - loss: 0.7495 - accuracy: 0.7488 - precision: 0.8238 - recall: 0.6706 - f1_score: 0.7393 - val_loss: 0.7206 - val_accuracy: 0.7598 - val_precision: 0.8566 - val_recall: 0.6547 - val_f1_score: 0.7422 - lr: 5.0000e-04
# Epoch 13/100
# 624/624 [==============================] - ETA: 0s - loss: 0.7368 - accuracy: 0.7552 - precision: 0.8287 - recall: 0.6747 - f1_score: 0.7438
# Epoch 13: val_accuracy did not improve from 0.75982
# 624/624 [==============================] - 34s 55ms/step - loss: 0.7368 - accuracy: 0.7552 - precision: 0.8287 - recall: 0.6747 - f1_score: 0.7438 - val_loss: 0.9360 - val_accuracy: 0.7403 - val_precision: 0.9222 - val_recall: 0.4548 - val_f1_score: 0.6092 - lr: 5.0000e-04
# Epoch 14/100
# 623/624 [============================>.] - ETA: 0s - loss: 0.7352 - accuracy: 0.7550 - precision: 0.8275 - recall: 0.6754 - f1_score: 0.7437
# Epoch 14: val_accuracy did not improve from 0.75982
# 624/624 [==============================] - 34s 54ms/step - loss: 0.7355 - accuracy: 0.7548 - precision: 0.8273 - recall: 0.6751 - f1_score: 0.7435 - val_loss: 0.8077 - val_accuracy: 0.7415 - val_precision: 0.8301 - val_recall: 0.6410 - val_f1_score: 0.7234 - lr: 5.0000e-04
# Epoch 15/100
# 624/624 [==============================] - ETA: 0s - loss: 0.7233 - accuracy: 0.7592 - precision: 0.8327 - recall: 0.6818 - f1_score: 0.7497
# Epoch 15: val_accuracy did not improve from 0.75982
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 624/624 [==============================] - 33s 53ms/step - loss: 0.7233 - accuracy: 0.7592 - precision: 0.8327 - recall: 0.6818 - f1_score: 0.7497 - val_loss: 0.9808 - val_accuracy: 0.7283 - val_precision: 0.9199 - val_recall: 0.4429 - val_f1_score: 0.5979 - lr: 5.0000e-04
# Epoch 16/100
# 624/624 [==============================] - ETA: 0s - loss: 0.6959 - accuracy: 0.7685 - precision: 0.8381 - recall: 0.6940 - f1_score: 0.7592
# Epoch 16: val_accuracy improved from 0.75982 to 0.76392, saving model to models\modelo_S_com_data_augmentation.keras
# 624/624 [==============================] - 35s 56ms/step - loss: 0.6959 - accuracy: 0.7685 - precision: 0.8381 - recall: 0.6940 - f1_score: 0.7592 - val_loss: 0.8494 - val_accuracy: 0.7639 - val_precision: 0.9228 - val_recall: 0.5185 - val_f1_score: 0.6640 - lr: 2.5000e-04
# Epoch 17/100
# 624/624 [==============================] - ETA: 0s - loss: 0.6855 - accuracy: 0.7731 - precision: 0.8409 - recall: 0.6974 - f1_score: 0.7625
# Epoch 17: val_accuracy improved from 0.76392 to 0.76623, saving model to models\modelo_S_com_data_augmentation.keras
# 624/624 [==============================] - 34s 55ms/step - loss: 0.6855 - accuracy: 0.7731 - precision: 0.8409 - recall: 0.6974 - f1_score: 0.7625 - val_loss: 0.7971 - val_accuracy: 0.7662 - val_precision: 0.9089 - val_recall: 0.5515 - val_f1_score: 0.6864 - lr: 2.5000e-04
# Epoch 18/100
# 624/624 [==============================] - ETA: 0s - loss: 0.6737 - accuracy: 0.7770 - precision: 0.8441 - recall: 0.7033 - f1_score: 0.7673
# Epoch 18: val_accuracy improved from 0.76623 to 0.77774, saving model to models\modelo_S_com_data_augmentation.keras
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 624/624 [==============================] - 35s 55ms/step - loss: 0.6737 - accuracy: 0.7770 - precision: 0.8441 - recall: 0.7033 - f1_score: 0.7673 - val_loss: 0.8637 - val_accuracy: 0.7777 - val_precision: 0.9326 - val_recall: 0.5101 - val_f1_score: 0.6595 - lr: 2.5000e-04
# Epoch 19/100
# 624/624 [==============================] - ETA: 0s - loss: 0.6609 - accuracy: 0.7817 - precision: 0.8463 - recall: 0.7108 - f1_score: 0.7726
# Epoch 19: val_accuracy improved from 0.77774 to 0.79327, saving model to models\modelo_S_com_data_augmentation.keras
# 624/624 [==============================] - 33s 54ms/step - loss: 0.6609 - accuracy: 0.7817 - precision: 0.8463 - recall: 0.7108 - f1_score: 0.7726 - val_loss: 0.7615 - val_accuracy: 0.7933 - val_precision: 0.9322 - val_recall: 0.5649 - val_f1_score: 0.7035 - lr: 1.2500e-04
# Epoch 20/100
# 624/624 [==============================] - ETA: 0s - loss: 0.6572 - accuracy: 0.7816 - precision: 0.8453 - recall: 0.7095 - f1_score: 0.7715
# Epoch 20: val_accuracy did not improve from 0.79327
# 624/624 [==============================] - 33s 53ms/step - loss: 0.6572 - accuracy: 0.7816 - precision: 0.8453 - recall: 0.7095 - f1_score: 0.7715 - val_loss: 0.8968 - val_accuracy: 0.7731 - val_precision: 0.9387 - val_recall: 0.4787 - val_f1_score: 0.6340 - lr: 1.2500e-04
# Epoch 21/100
# 624/624 [==============================] - ETA: 0s - loss: 0.6478 - accuracy: 0.7859 - precision: 0.8481 - recall: 0.7147 - f1_score: 0.7757
# Epoch 21: val_accuracy did not improve from 0.79327
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 624/624 [==============================] - 34s 55ms/step - loss: 0.6478 - accuracy: 0.7859 - precision: 0.8481 - recall: 0.7147 - f1_score: 0.7757 - val_loss: 0.7798 - val_accuracy: 0.7919 - val_precision: 0.9329 - val_recall: 0.5518 - val_f1_score: 0.6934 - lr: 1.2500e-04
# Epoch 22/100
# 624/624 [==============================] - ETA: 0s - loss: 0.6448 - accuracy: 0.7861 - precision: 0.8496 - recall: 0.7137 - f1_score: 0.7758
# Epoch 22: val_accuracy did not improve from 0.79327
# 624/624 [==============================] - 33s 54ms/step - loss: 0.6448 - accuracy: 0.7861 - precision: 0.8496 - recall: 0.7137 - f1_score: 0.7758 - val_loss: 0.7598 - val_accuracy: 0.7911 - val_precision: 0.9265 - val_recall: 0.5718 - val_f1_score: 0.7072 - lr: 6.2500e-05
# 157/157 [==============================] - 6s 41ms/step - loss: 0.7160 - accuracy: 0.7659 - precision: 0.8522 - recall: 0.6639 - f1_score: 0.7464
# Test Loss: 0.7160398364067078
# Test Accuracy: 0.7659000158309937
# Test Precision: 0.8522464632987976
# Test Recall: 0.6639000177383423
# Test F1 Score: 0.7463743090629578

# %%
# Plot training history
plt.figure(figsize=(12, 8))
plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(history.history['val_precision'], label='val_precision')
plt.plot(history.history['val_recall'], label='val_recall')
plt.plot(history.history['val_f1_score'], label='val_f1_score')
plt.xlabel('Epoch')
plt.ylabel('Metrics')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.title('Validation Precision, Recall, F1 Score')

plt.savefig(
    f'./plots/modelo_S_com_data_augmentation_rmsprop.png')
plt.tight_layout()
