# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
# CONSTANTES
BATCH_SIZE = 32
IMG_SIZE = 32
NUM_CLASSES = 10  # nº classes para identificar
NUM_EPOCHS = 60
LEARNING_RATE = 0.001

# %%
# Define directories
train_dirs = ['./dataset/train/train1', './dataset/train/train2', './dataset/train/train3', './dataset/train/train5']
validation_dir = './dataset/validation'
test_dir = './dataset/test'

# %%
# CRIAR OS GERADORES
train_datagen = ImageDataGenerator(rescale=1./255)

validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# training generators
train_generators = [train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical') for train_dir in train_dirs]

# Necessário para junstar os trainning generators
def combined_generator(generators):
    while True:
        for generator in generators:
            yield next(generator)

train_generator = combined_generator(train_generators)

# Validation e test generators
validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical')
# Out:
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.

# %%
from tensorflow.keras import backend as K
from tensorflow.keras.metrics import Metric

class Precision(Metric):
    def __init__(self, name='precision', **kwargs):
        super(Precision, self).__init__(name=name, **kwargs)
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.predicted_positives = self.add_weight(name='pp', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = K.round(y_pred)
        y_true = K.cast(y_true, 'float32')
        self.true_positives.assign_add(K.sum(y_true * y_pred))
        self.predicted_positives.assign_add(K.sum(y_pred))

    def result(self):
        return self.true_positives / (self.predicted_positives + K.epsilon())

    def reset_states(self):
        self.true_positives.assign(0)
        self.predicted_positives.assign(0)

class Recall(Metric):
    def __init__(self, name='recall', **kwargs):
        super(Recall, self).__init__(name=name, **kwargs)
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.actual_positives = self.add_weight(name='ap', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = K.round(y_pred)
        y_true = K.cast(y_true, 'float32')
        self.true_positives.assign_add(K.sum(y_true * y_pred))
        self.actual_positives.assign_add(K.sum(y_true))

    def result(self):
        return self.true_positives / (self.actual_positives + K.epsilon())

    def reset_states(self):
        self.true_positives.assign(0)
        self.actual_positives.assign(0)

class F1Score(Metric):
    def __init__(self, name='f1_score', **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.precision = Precision()
        self.recall = Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred)
        self.recall.update_state(y_true, y_pred)

    def result(self):
        precision = self.precision.result()
        recall = self.recall.result()
        return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

    def reset_states(self):
        self.precision.reset_states()
        self.recall.reset_states()

# %%
model = Sequential([
    Conv2D(128, (3, 3), input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.3),
    
    Conv2D(256, (3, 3)),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.5),
    
    Conv2D(512, (3, 3)),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.5),
    
    Flatten(),
    Dense(512),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),
    
    Dense(NUM_CLASSES, activation='softmax')
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=LEARNING_RATE),
              loss='categorical_crossentropy',
              metrics=['accuracy', Precision(), Recall(), F1Score()])


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 128)       3584
#
#  batch_normalization (BatchN  (None, 30, 30, 128)      512
#  ormalization)
#
#  activation (Activation)     (None, 30, 30, 128)       0
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 128)      0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 128)       0
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 256)       295168
#
#  batch_normalization_1 (Batc  (None, 13, 13, 256)      1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 13, 13, 256)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 256)         0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 512)         1180160
#
#  batch_normalization_2 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  activation_2 (Activation)   (None, 4, 4, 512)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  batch_normalization_3 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation_3 (Activation)   (None, 512)               0
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 2,538,762
# Trainable params: 2,535,946
# Non-trainable params: 2,816
# _________________________________________________________________

# %%
# Definir os Callbacks

# Para salvar o melhor modelo com base na acurácia de validação
checkpoint = ModelCheckpoint("models/modelo_S_sem_data_augmentation_adam_sem_reducelr_e_earlystopping.keras", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# Salvar para csv
csv_logger = CSVLogger(f'logs/modelo_S_sem_data_augmentation_adam_sem_reducelr_e_earlystopping.csv', append=True)

# %%
# Calculate steps per epoch
steps_per_epoch = sum([gen.samples // BATCH_SIZE for gen in train_generators])

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=NUM_EPOCHS,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // BATCH_SIZE,
    callbacks=[checkpoint, csv_logger]
)


# Evaluate the model
results = model.evaluate(test_generator)
loss, accuracy, precision, recall, f1_score = results[:5]
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
print(f"Test Precision: {precision}")
print(f"Test Recall: {recall}")
print(f"Test F1 Score: {f1_score}")
# Out:
# Epoch 1/60
# 1248/1248 [==============================] - ETA: 0s - loss: 1.6281 - accuracy: 0.4288 - precision: 0.5695 - recall: 0.2644 - f1_score: 0.3611
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric Precision implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric Recall implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# Epoch 1: val_accuracy improved from -inf to 0.45202, saving model to models\modelo_S_sem_data_augmentation_adam_sem_reducelr_e_earlystopping.keras
# 1248/1248 [==============================] - 32s 22ms/step - loss: 1.6281 - accuracy: 0.4288 - precision: 0.5695 - recall: 0.2644 - f1_score: 0.3611 - val_loss: 1.5834 - val_accuracy: 0.4520 - val_precision: 0.6053 - val_recall: 0.3438 - val_f1_score: 0.4385
# Epoch 2/60
# 1248/1248 [==============================] - ETA: 0s - loss: 1.2283 - accuracy: 0.5619 - precision: 0.7054 - recall: 0.4087 - f1_score: 0.5176
# Epoch 2: val_accuracy improved from 0.45202 to 0.50130, saving model to models\modelo_S_sem_data_augmentation_adam_sem_reducelr_e_earlystopping.keras
# 1248/1248 [==============================] - 19s 15ms/step - loss: 1.2283 - accuracy: 0.5619 - precision: 0.7054 - recall: 0.4087 - f1_score: 0.5176 - val_loss: 1.4364 - val_accuracy: 0.5013 - val_precision: 0.6051 - val_recall: 0.3703 - val_f1_score: 0.4594
# Epoch 3/60
# 1246/1248 [============================>.] - ETA: 0s - loss: 1.1034 - accuracy: 0.6096 - precision: 0.7387 - recall: 0.4734 - f1_score: 0.5770
# Epoch 3: val_accuracy improved from 0.50130 to 0.57792, saving model to models\modelo_S_sem_data_augmentation_adam_sem_reducelr_e_earlystopping.keras
# 1248/1248 [==============================] - 17s 14ms/step - loss: 1.1038 - accuracy: 0.6095 - precision: 0.7387 - recall: 0.4734 - f1_score: 0.5770 - val_loss: 1.1910 - val_accuracy: 0.5779 - val_precision: 0.6904 - val_recall: 0.4689 - val_f1_score: 0.5585
# Epoch 4/60
# 1244/1248 [============================>.] - ETA: 0s - loss: 1.0077 - accuracy: 0.6459 - precision: 0.7649 - recall: 0.5274 - f1_score: 0.6243
# Epoch 4: val_accuracy did not improve from 0.57792
# 1248/1248 [==============================] - 17s 14ms/step - loss: 1.0075 - accuracy: 0.6458 - precision: 0.7648 - recall: 0.5274 - f1_score: 0.6243 - val_loss: 1.2471 - val_accuracy: 0.5737 - val_precision: 0.6847 - val_recall: 0.4526 - val_f1_score: 0.5450
# Epoch 5/60
# 1248/1248 [==============================] - ETA: 0s - loss: 0.9515 - accuracy: 0.6660 - precision: 0.7747 - recall: 0.5590 - f1_score: 0.6494
# Epoch 5: val_accuracy did not improve from 0.57792
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.9515 - accuracy: 0.6660 - precision: 0.7747 - recall: 0.5590 - f1_score: 0.6494 - val_loss: 1.3775 - val_accuracy: 0.5399 - val_precision: 0.6170 - val_recall: 0.4553 - val_f1_score: 0.5240
# Epoch 6/60
# 1248/1248 [==============================] - ETA: 0s - loss: 0.9004 - accuracy: 0.6840 - precision: 0.7838 - recall: 0.5838 - f1_score: 0.6692
# Epoch 6: val_accuracy improved from 0.57792 to 0.64824, saving model to models\modelo_S_sem_data_augmentation_adam_sem_reducelr_e_earlystopping.keras
# 1248/1248 [==============================] - 20s 16ms/step - loss: 0.9004 - accuracy: 0.6840 - precision: 0.7838 - recall: 0.5838 - f1_score: 0.6692 - val_loss: 1.0240 - val_accuracy: 0.6482 - val_precision: 0.7381 - val_recall: 0.5655 - val_f1_score: 0.6404
# Epoch 7/60
# 1244/1248 [============================>.] - ETA: 0s - loss: 0.8554 - accuracy: 0.7001 - precision: 0.7928 - recall: 0.6067 - f1_score: 0.6874
# Epoch 7: val_accuracy improved from 0.64824 to 0.68730, saving model to models\modelo_S_sem_data_augmentation_adam_sem_reducelr_e_earlystopping.keras
# 1248/1248 [==============================] - 20s 16ms/step - loss: 0.8556 - accuracy: 0.7000 - precision: 0.7927 - recall: 0.6066 - f1_score: 0.6873 - val_loss: 0.9172 - val_accuracy: 0.6873 - val_precision: 0.7954 - val_recall: 0.5864 - val_f1_score: 0.6751
# Epoch 8/60
# 1246/1248 [============================>.] - ETA: 0s - loss: 0.8107 - accuracy: 0.7181 - precision: 0.8076 - recall: 0.6334 - f1_score: 0.7100
# Epoch 8: val_accuracy improved from 0.68730 to 0.69071, saving model to models\modelo_S_sem_data_augmentation_adam_sem_reducelr_e_earlystopping.keras
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.8105 - accuracy: 0.7182 - precision: 0.8077 - recall: 0.6335 - f1_score: 0.7101 - val_loss: 0.8808 - val_accuracy: 0.6907 - val_precision: 0.7857 - val_recall: 0.6162 - val_f1_score: 0.6907
# Epoch 9/60
# 1244/1248 [============================>.] - ETA: 0s - loss: 0.7854 - accuracy: 0.7272 - precision: 0.8135 - recall: 0.6466 - f1_score: 0.7205
# Epoch 9: val_accuracy did not improve from 0.69071
# 1248/1248 [==============================] - 18s 14ms/step - loss: 0.7852 - accuracy: 0.7274 - precision: 0.8137 - recall: 0.6467 - f1_score: 0.7207 - val_loss: 1.0417 - val_accuracy: 0.6541 - val_precision: 0.7419 - val_recall: 0.5850 - val_f1_score: 0.6542
# Epoch 10/60
# 1246/1248 [============================>.] - ETA: 0s - loss: 0.7519 - accuracy: 0.7387 - precision: 0.8197 - recall: 0.6614 - f1_score: 0.7321
# Epoch 10: val_accuracy improved from 0.69071 to 0.70343, saving model to models\modelo_S_sem_data_augmentation_adam_sem_reducelr_e_earlystopping.keras
# 1248/1248 [==============================] - 16s 13ms/step - loss: 0.7516 - accuracy: 0.7389 - precision: 0.8198 - recall: 0.6615 - f1_score: 0.7322 - val_loss: 0.8357 - val_accuracy: 0.7034 - val_precision: 0.7787 - val_recall: 0.6328 - val_f1_score: 0.6982
# Epoch 11/60
# 1248/1248 [==============================] - ETA: 0s - loss: 0.7199 - accuracy: 0.7500 - precision: 0.8272 - recall: 0.6780 - f1_score: 0.7452
# Epoch 11: val_accuracy improved from 0.70343 to 0.71244, saving model to models\modelo_S_sem_data_augmentation_adam_sem_reducelr_e_earlystopping.keras
# 1248/1248 [==============================] - 17s 13ms/step - loss: 0.7199 - accuracy: 0.7500 - precision: 0.8272 - recall: 0.6780 - f1_score: 0.7452 - val_loss: 0.8307 - val_accuracy: 0.7124 - val_precision: 0.8029 - val_recall: 0.6320 - val_f1_score: 0.7073
# Epoch 12/60
# 1246/1248 [============================>.] - ETA: 0s - loss: 0.6974 - accuracy: 0.7574 - precision: 0.8307 - recall: 0.6882 - f1_score: 0.7528
# Epoch 12: val_accuracy did not improve from 0.71244
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.6972 - accuracy: 0.7575 - precision: 0.8308 - recall: 0.6882 - f1_score: 0.7528 - val_loss: 1.0073 - val_accuracy: 0.6568 - val_precision: 0.7274 - val_recall: 0.5975 - val_f1_score: 0.6560
# Epoch 13/60
# 1248/1248 [==============================] - ETA: 0s - loss: 0.6799 - accuracy: 0.7641 - precision: 0.8337 - recall: 0.6973 - f1_score: 0.7594
# Epoch 13: val_accuracy did not improve from 0.71244
# 1248/1248 [==============================] - 17s 13ms/step - loss: 0.6799 - accuracy: 0.7641 - precision: 0.8337 - recall: 0.6973 - f1_score: 0.7594 - val_loss: 0.9028 - val_accuracy: 0.6870 - val_precision: 0.7558 - val_recall: 0.6283 - val_f1_score: 0.6862
# Epoch 14/60
# 1248/1248 [==============================] - ETA: 0s - loss: 0.6529 - accuracy: 0.7714 - precision: 0.8395 - recall: 0.7103 - f1_score: 0.7695
# Epoch 14: val_accuracy improved from 0.71244 to 0.72766, saving model to models\modelo_S_sem_data_augmentation_adam_sem_reducelr_e_earlystopping.keras
# 1248/1248 [==============================] - 18s 14ms/step - loss: 0.6529 - accuracy: 0.7714 - precision: 0.8395 - recall: 0.7103 - f1_score: 0.7695 - val_loss: 0.7925 - val_accuracy: 0.7277 - val_precision: 0.7887 - val_recall: 0.6679 - val_f1_score: 0.7233
# Epoch 15/60
# 1248/1248 [==============================] - ETA: 0s - loss: 0.6433 - accuracy: 0.7734 - precision: 0.8390 - recall: 0.7130 - f1_score: 0.7709
# Epoch 15: val_accuracy did not improve from 0.72766
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.6433 - accuracy: 0.7734 - precision: 0.8390 - recall: 0.7130 - f1_score: 0.7709 - val_loss: 0.9210 - val_accuracy: 0.6902 - val_precision: 0.7665 - val_recall: 0.6269 - val_f1_score: 0.6897
# Epoch 16/60
# 1244/1248 [============================>.] - ETA: 0s - loss: 0.6188 - accuracy: 0.7841 - precision: 0.8463 - recall: 0.7265 - f1_score: 0.7818
# Epoch 16: val_accuracy improved from 0.72766 to 0.79006, saving model to models\modelo_S_sem_data_augmentation_adam_sem_reducelr_e_earlystopping.keras
# 1248/1248 [==============================] - 16s 13ms/step - loss: 0.6182 - accuracy: 0.7843 - precision: 0.8466 - recall: 0.7268 - f1_score: 0.7821 - val_loss: 0.6016 - val_accuracy: 0.7901 - val_precision: 0.8567 - val_recall: 0.7352 - val_f1_score: 0.7913
# Epoch 17/60
# 1244/1248 [============================>.] - ETA: 0s - loss: 0.6114 - accuracy: 0.7855 - precision: 0.8453 - recall: 0.7299 - f1_score: 0.7834
# Epoch 17: val_accuracy did not improve from 0.79006
# 1248/1248 [==============================] - 17s 13ms/step - loss: 0.6116 - accuracy: 0.7854 - precision: 0.8452 - recall: 0.7298 - f1_score: 0.7833 - val_loss: 0.6701 - val_accuracy: 0.7697 - val_precision: 0.8384 - val_recall: 0.7129 - val_f1_score: 0.7706
# Epoch 18/60
# 1244/1248 [============================>.] - ETA: 0s - loss: 0.5875 - accuracy: 0.7928 - precision: 0.8515 - recall: 0.7400 - f1_score: 0.7918
# Epoch 18: val_accuracy did not improve from 0.79006
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.5877 - accuracy: 0.7927 - precision: 0.8514 - recall: 0.7398 - f1_score: 0.7917 - val_loss: 0.8399 - val_accuracy: 0.7164 - val_precision: 0.7825 - val_recall: 0.6520 - val_f1_score: 0.7114
# Epoch 19/60
# 1247/1248 [============================>.] - ETA: 0s - loss: 0.5800 - accuracy: 0.7963 - precision: 0.8523 - recall: 0.7450 - f1_score: 0.7950
# Epoch 19: val_accuracy did not improve from 0.79006
# 1248/1248 [==============================] - 17s 13ms/step - loss: 0.5799 - accuracy: 0.7964 - precision: 0.8523 - recall: 0.7450 - f1_score: 0.7951 - val_loss: 0.6617 - val_accuracy: 0.7703 - val_precision: 0.8358 - val_recall: 0.7197 - val_f1_score: 0.7734
# Epoch 20/60
# 1244/1248 [============================>.] - ETA: 0s - loss: 0.5636 - accuracy: 0.8000 - precision: 0.8535 - recall: 0.7502 - f1_score: 0.7985
# Epoch 20: val_accuracy did not improve from 0.79006
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.5637 - accuracy: 0.8001 - precision: 0.8534 - recall: 0.7503 - f1_score: 0.7985 - val_loss: 0.8404 - val_accuracy: 0.7168 - val_precision: 0.7874 - val_recall: 0.6590 - val_f1_score: 0.7175
# Epoch 21/60
# 1246/1248 [============================>.] - ETA: 0s - loss: 0.5539 - accuracy: 0.8052 - precision: 0.8582 - recall: 0.7563 - f1_score: 0.8040
# Epoch 21: val_accuracy did not improve from 0.79006
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.5538 - accuracy: 0.8053 - precision: 0.8583 - recall: 0.7563 - f1_score: 0.8041 - val_loss: 0.7756 - val_accuracy: 0.7458 - val_precision: 0.8126 - val_recall: 0.6914 - val_f1_score: 0.7471
# Epoch 22/60
# 1244/1248 [============================>.] - ETA: 0s - loss: 0.5425 - accuracy: 0.8105 - precision: 0.8635 - recall: 0.7628 - f1_score: 0.8101
# Epoch 22: val_accuracy did not improve from 0.79006
# 1248/1248 [==============================] - 17s 13ms/step - loss: 0.5429 - accuracy: 0.8104 - precision: 0.8633 - recall: 0.7626 - f1_score: 0.8099 - val_loss: 0.8129 - val_accuracy: 0.7282 - val_precision: 0.7892 - val_recall: 0.6778 - val_f1_score: 0.7293
# Epoch 23/60
# 1244/1248 [============================>.] - ETA: 0s - loss: 0.5339 - accuracy: 0.8125 - precision: 0.8620 - recall: 0.7663 - f1_score: 0.8113
# Epoch 23: val_accuracy improved from 0.79006 to 0.79357, saving model to models\modelo_S_sem_data_augmentation_adam_sem_reducelr_e_earlystopping.keras
# 1248/1248 [==============================] - 16s 13ms/step - loss: 0.5340 - accuracy: 0.8123 - precision: 0.8620 - recall: 0.7661 - f1_score: 0.8112 - val_loss: 0.5973 - val_accuracy: 0.7936 - val_precision: 0.8499 - val_recall: 0.7491 - val_f1_score: 0.7963
# Epoch 24/60
# 1246/1248 [============================>.] - ETA: 0s - loss: 0.5233 - accuracy: 0.8181 - precision: 0.8664 - recall: 0.7736 - f1_score: 0.8174
# Epoch 24: val_accuracy did not improve from 0.79357
# 1248/1248 [==============================] - 18s 14ms/step - loss: 0.5233 - accuracy: 0.8182 - precision: 0.8664 - recall: 0.7736 - f1_score: 0.8174 - val_loss: 0.6514 - val_accuracy: 0.7788 - val_precision: 0.8487 - val_recall: 0.7169 - val_f1_score: 0.7773
# Epoch 25/60
# 1247/1248 [============================>.] - ETA: 0s - loss: 0.5098 - accuracy: 0.8199 - precision: 0.8675 - recall: 0.7762 - f1_score: 0.8193
# Epoch 25: val_accuracy did not improve from 0.79357
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.5097 - accuracy: 0.8198 - precision: 0.8675 - recall: 0.7762 - f1_score: 0.8193 - val_loss: 0.5996 - val_accuracy: 0.7930 - val_precision: 0.8497 - val_recall: 0.7499 - val_f1_score: 0.7967
# Epoch 26/60
# 1248/1248 [==============================] - ETA: 0s - loss: 0.5031 - accuracy: 0.8232 - precision: 0.8715 - recall: 0.7810 - f1_score: 0.8238
# Epoch 26: val_accuracy did not improve from 0.79357
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.5031 - accuracy: 0.8232 - precision: 0.8715 - recall: 0.7810 - f1_score: 0.8238 - val_loss: 0.7868 - val_accuracy: 0.7386 - val_precision: 0.7943 - val_recall: 0.6968 - val_f1_score: 0.7424
# Epoch 27/60
# 1248/1248 [==============================] - ETA: 0s - loss: 0.5015 - accuracy: 0.8255 - precision: 0.8710 - recall: 0.7840 - f1_score: 0.8252
# Epoch 27: val_accuracy did not improve from 0.79357
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.5015 - accuracy: 0.8255 - precision: 0.8710 - recall: 0.7840 - f1_score: 0.8252 - val_loss: 0.8481 - val_accuracy: 0.7264 - val_precision: 0.7790 - val_recall: 0.6829 - val_f1_score: 0.7278
# Epoch 28/60
# 1246/1248 [============================>.] - ETA: 0s - loss: 0.4933 - accuracy: 0.8248 - precision: 0.8701 - recall: 0.7861 - f1_score: 0.8260
# Epoch 28: val_accuracy did not improve from 0.79357
# 1248/1248 [==============================] - 18s 15ms/step - loss: 0.4934 - accuracy: 0.8249 - precision: 0.8701 - recall: 0.7861 - f1_score: 0.8259 - val_loss: 0.9458 - val_accuracy: 0.6947 - val_precision: 0.7461 - val_recall: 0.6530 - val_f1_score: 0.6965
# Epoch 29/60
# 1248/1248 [==============================] - ETA: 0s - loss: 0.4861 - accuracy: 0.8292 - precision: 0.8715 - recall: 0.7900 - f1_score: 0.8287
# Epoch 29: val_accuracy did not improve from 0.79357
# 1248/1248 [==============================] - 18s 14ms/step - loss: 0.4861 - accuracy: 0.8292 - precision: 0.8715 - recall: 0.7900 - f1_score: 0.8287 - val_loss: 0.6993 - val_accuracy: 0.7682 - val_precision: 0.8192 - val_recall: 0.7261 - val_f1_score: 0.7698
# Epoch 30/60
# 1247/1248 [============================>.] - ETA: 0s - loss: 0.4787 - accuracy: 0.8320 - precision: 0.8729 - recall: 0.7925 - f1_score: 0.8308
# Epoch 30: val_accuracy did not improve from 0.79357
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.4791 - accuracy: 0.8319 - precision: 0.8728 - recall: 0.7925 - f1_score: 0.8307 - val_loss: 0.6463 - val_accuracy: 0.7807 - val_precision: 0.8307 - val_recall: 0.7399 - val_f1_score: 0.7827
# Epoch 31/60
# 1246/1248 [============================>.] - ETA: 0s - loss: 0.4786 - accuracy: 0.8327 - precision: 0.8738 - recall: 0.7926 - f1_score: 0.8312
# Epoch 31: val_accuracy improved from 0.79357 to 0.81450, saving model to models\modelo_S_sem_data_augmentation_adam_sem_reducelr_e_earlystopping.keras
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.4789 - accuracy: 0.8327 - precision: 0.8737 - recall: 0.7925 - f1_score: 0.8311 - val_loss: 0.5464 - val_accuracy: 0.8145 - val_precision: 0.8667 - val_recall: 0.7701 - val_f1_score: 0.8155
# Epoch 32/60
# 1248/1248 [==============================] - ETA: 0s - loss: 0.4650 - accuracy: 0.8368 - precision: 0.8772 - recall: 0.8003 - f1_score: 0.8370
# Epoch 32: val_accuracy did not improve from 0.81450
# 1248/1248 [==============================] - 17s 13ms/step - loss: 0.4650 - accuracy: 0.8368 - precision: 0.8772 - recall: 0.8003 - f1_score: 0.8370 - val_loss: 0.5590 - val_accuracy: 0.8076 - val_precision: 0.8611 - val_recall: 0.7677 - val_f1_score: 0.8118
# Epoch 33/60
# 1246/1248 [============================>.] - ETA: 0s - loss: 0.4590 - accuracy: 0.8388 - precision: 0.8787 - recall: 0.8005 - f1_score: 0.8378
# Epoch 33: val_accuracy did not improve from 0.81450
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.4592 - accuracy: 0.8388 - precision: 0.8787 - recall: 0.8005 - f1_score: 0.8378 - val_loss: 0.7715 - val_accuracy: 0.7452 - val_precision: 0.7956 - val_recall: 0.7034 - val_f1_score: 0.7467
# Epoch 34/60
# 1247/1248 [============================>.] - ETA: 0s - loss: 0.4580 - accuracy: 0.8396 - precision: 0.8788 - recall: 0.8035 - f1_score: 0.8395
# Epoch 34: val_accuracy improved from 0.81450 to 0.82442, saving model to models\modelo_S_sem_data_augmentation_adam_sem_reducelr_e_earlystopping.keras
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.4579 - accuracy: 0.8396 - precision: 0.8788 - recall: 0.8035 - f1_score: 0.8395 - val_loss: 0.5106 - val_accuracy: 0.8244 - val_precision: 0.8785 - val_recall: 0.7796 - val_f1_score: 0.8261
# Epoch 35/60
# 1244/1248 [============================>.] - ETA: 0s - loss: 0.4550 - accuracy: 0.8389 - precision: 0.8782 - recall: 0.8044 - f1_score: 0.8397
# Epoch 35: val_accuracy did not improve from 0.82442
# 1248/1248 [==============================] - 18s 14ms/step - loss: 0.4547 - accuracy: 0.8390 - precision: 0.8784 - recall: 0.8046 - f1_score: 0.8398 - val_loss: 0.6255 - val_accuracy: 0.7899 - val_precision: 0.8414 - val_recall: 0.7468 - val_f1_score: 0.7913
# Epoch 36/60
# 1245/1248 [============================>.] - ETA: 0s - loss: 0.4437 - accuracy: 0.8448 - precision: 0.8823 - recall: 0.8110 - f1_score: 0.8451
# Epoch 36: val_accuracy did not improve from 0.82442
# 1248/1248 [==============================] - 18s 14ms/step - loss: 0.4440 - accuracy: 0.8447 - precision: 0.8821 - recall: 0.8109 - f1_score: 0.8450 - val_loss: 0.6111 - val_accuracy: 0.7956 - val_precision: 0.8473 - val_recall: 0.7556 - val_f1_score: 0.7988
# Epoch 37/60
# 1248/1248 [==============================] - ETA: 0s - loss: 0.4346 - accuracy: 0.8465 - precision: 0.8850 - recall: 0.8129 - f1_score: 0.8474
# Epoch 37: val_accuracy did not improve from 0.82442
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.4346 - accuracy: 0.8465 - precision: 0.8850 - recall: 0.8129 - f1_score: 0.8474 - val_loss: 0.9011 - val_accuracy: 0.7208 - val_precision: 0.7565 - val_recall: 0.6884 - val_f1_score: 0.7209
# Epoch 38/60
# 1245/1248 [============================>.] - ETA: 0s - loss: 0.4393 - accuracy: 0.8462 - precision: 0.8826 - recall: 0.8134 - f1_score: 0.8466
# Epoch 38: val_accuracy did not improve from 0.82442
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.4390 - accuracy: 0.8463 - precision: 0.8826 - recall: 0.8135 - f1_score: 0.8467 - val_loss: 0.6125 - val_accuracy: 0.7954 - val_precision: 0.8517 - val_recall: 0.7528 - val_f1_score: 0.7992
# Epoch 39/60
# 1248/1248 [==============================] - ETA: 0s - loss: 0.4310 - accuracy: 0.8481 - precision: 0.8833 - recall: 0.8153 - f1_score: 0.8479
# Epoch 39: val_accuracy did not improve from 0.82442
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.4310 - accuracy: 0.8481 - precision: 0.8833 - recall: 0.8153 - f1_score: 0.8479 - val_loss: 0.5771 - val_accuracy: 0.8086 - val_precision: 0.8560 - val_recall: 0.7652 - val_f1_score: 0.8081
# Epoch 40/60
# 1246/1248 [============================>.] - ETA: 0s - loss: 0.4244 - accuracy: 0.8520 - precision: 0.8860 - recall: 0.8210 - f1_score: 0.8523
# Epoch 40: val_accuracy did not improve from 0.82442
# 1248/1248 [==============================] - 17s 13ms/step - loss: 0.4247 - accuracy: 0.8519 - precision: 0.8859 - recall: 0.8209 - f1_score: 0.8521 - val_loss: 0.8507 - val_accuracy: 0.7309 - val_precision: 0.7805 - val_recall: 0.6937 - val_f1_score: 0.7345
# Epoch 41/60
# 1248/1248 [==============================] - ETA: 0s - loss: 0.4162 - accuracy: 0.8533 - precision: 0.8864 - recall: 0.8221 - f1_score: 0.8531
# Epoch 41: val_accuracy did not improve from 0.82442
# 1248/1248 [==============================] - 16s 13ms/step - loss: 0.4162 - accuracy: 0.8533 - precision: 0.8864 - recall: 0.8221 - f1_score: 0.8531 - val_loss: 0.7909 - val_accuracy: 0.7480 - val_precision: 0.7952 - val_recall: 0.7144 - val_f1_score: 0.7527
# Epoch 42/60
# 1245/1248 [============================>.] - ETA: 0s - loss: 0.4140 - accuracy: 0.8545 - precision: 0.8877 - recall: 0.8251 - f1_score: 0.8553
# Epoch 42: val_accuracy did not improve from 0.82442
# 1248/1248 [==============================] - 16s 13ms/step - loss: 0.4143 - accuracy: 0.8545 - precision: 0.8877 - recall: 0.8251 - f1_score: 0.8553 - val_loss: 0.5912 - val_accuracy: 0.8027 - val_precision: 0.8540 - val_recall: 0.7646 - val_f1_score: 0.8068
# Epoch 43/60
# 1243/1248 [============================>.] - ETA: 0s - loss: 0.4154 - accuracy: 0.8548 - precision: 0.8884 - recall: 0.8247 - f1_score: 0.8554
# Epoch 43: val_accuracy did not improve from 0.82442
# 1248/1248 [==============================] - 17s 13ms/step - loss: 0.4158 - accuracy: 0.8547 - precision: 0.8883 - recall: 0.8245 - f1_score: 0.8552 - val_loss: 0.5558 - val_accuracy: 0.8126 - val_precision: 0.8561 - val_recall: 0.7747 - val_f1_score: 0.8134
# Epoch 44/60
# 1244/1248 [============================>.] - ETA: 0s - loss: 0.4014 - accuracy: 0.8568 - precision: 0.8898 - recall: 0.8296 - f1_score: 0.8587
# Epoch 44: val_accuracy did not improve from 0.82442
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.4015 - accuracy: 0.8568 - precision: 0.8899 - recall: 0.8297 - f1_score: 0.8587 - val_loss: 0.6652 - val_accuracy: 0.7839 - val_precision: 0.8283 - val_recall: 0.7477 - val_f1_score: 0.7860
# Epoch 45/60
# 1247/1248 [============================>.] - ETA: 0s - loss: 0.4038 - accuracy: 0.8596 - precision: 0.8906 - recall: 0.8316 - f1_score: 0.8601
# Epoch 45: val_accuracy did not improve from 0.82442
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.4039 - accuracy: 0.8595 - precision: 0.8906 - recall: 0.8316 - f1_score: 0.8601 - val_loss: 0.7635 - val_accuracy: 0.7556 - val_precision: 0.8012 - val_recall: 0.7157 - val_f1_score: 0.7561
# Epoch 46/60
# 1248/1248 [==============================] - ETA: 0s - loss: 0.4044 - accuracy: 0.8583 - precision: 0.8887 - recall: 0.8279 - f1_score: 0.8572
# Epoch 46: val_accuracy did not improve from 0.82442
# 1248/1248 [==============================] - 16s 13ms/step - loss: 0.4044 - accuracy: 0.8583 - precision: 0.8887 - recall: 0.8279 - f1_score: 0.8572 - val_loss: 0.6380 - val_accuracy: 0.7906 - val_precision: 0.8412 - val_recall: 0.7555 - val_f1_score: 0.7961
# Epoch 47/60
# 1245/1248 [============================>.] - ETA: 0s - loss: 0.3910 - accuracy: 0.8633 - precision: 0.8935 - recall: 0.8369 - f1_score: 0.8643
# Epoch 47: val_accuracy did not improve from 0.82442
# 1248/1248 [==============================] - 16s 13ms/step - loss: 0.3910 - accuracy: 0.8633 - precision: 0.8935 - recall: 0.8369 - f1_score: 0.8643 - val_loss: 0.5464 - val_accuracy: 0.8130 - val_precision: 0.8683 - val_recall: 0.7729 - val_f1_score: 0.8179
# Epoch 48/60
# 1244/1248 [============================>.] - ETA: 0s - loss: 0.3855 - accuracy: 0.8636 - precision: 0.8941 - recall: 0.8374 - f1_score: 0.8648
# Epoch 48: val_accuracy did not improve from 0.82442
# 1248/1248 [==============================] - 16s 13ms/step - loss: 0.3858 - accuracy: 0.8637 - precision: 0.8941 - recall: 0.8374 - f1_score: 0.8648 - val_loss: 0.6044 - val_accuracy: 0.8028 - val_precision: 0.8489 - val_recall: 0.7662 - val_f1_score: 0.8054
# Epoch 49/60
# 1248/1248 [==============================] - ETA: 0s - loss: 0.3882 - accuracy: 0.8642 - precision: 0.8947 - recall: 0.8371 - f1_score: 0.8649
# Epoch 49: val_accuracy did not improve from 0.82442
# 1248/1248 [==============================] - 17s 13ms/step - loss: 0.3882 - accuracy: 0.8642 - precision: 0.8947 - recall: 0.8371 - f1_score: 0.8649 - val_loss: 0.5915 - val_accuracy: 0.8014 - val_precision: 0.8560 - val_recall: 0.7643 - val_f1_score: 0.8076
# Epoch 50/60
# 1245/1248 [============================>.] - ETA: 0s - loss: 0.3816 - accuracy: 0.8662 - precision: 0.8939 - recall: 0.8399 - f1_score: 0.8661
# Epoch 50: val_accuracy did not improve from 0.82442
# 1248/1248 [==============================] - 16s 13ms/step - loss: 0.3817 - accuracy: 0.8662 - precision: 0.8938 - recall: 0.8399 - f1_score: 0.8660 - val_loss: 0.6772 - val_accuracy: 0.7814 - val_precision: 0.8295 - val_recall: 0.7450 - val_f1_score: 0.7850
# Epoch 51/60
# 1247/1248 [============================>.] - ETA: 0s - loss: 0.3772 - accuracy: 0.8688 - precision: 0.8978 - recall: 0.8421 - f1_score: 0.8691
# Epoch 51: val_accuracy did not improve from 0.82442
# 1248/1248 [==============================] - 17s 13ms/step - loss: 0.3771 - accuracy: 0.8688 - precision: 0.8978 - recall: 0.8421 - f1_score: 0.8691 - val_loss: 0.5985 - val_accuracy: 0.8013 - val_precision: 0.8514 - val_recall: 0.7652 - val_f1_score: 0.8060
# Epoch 52/60
# 1246/1248 [============================>.] - ETA: 0s - loss: 0.3867 - accuracy: 0.8625 - precision: 0.8924 - recall: 0.8356 - f1_score: 0.8630
# Epoch 52: val_accuracy did not improve from 0.82442
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.3868 - accuracy: 0.8625 - precision: 0.8925 - recall: 0.8356 - f1_score: 0.8631 - val_loss: 0.5143 - val_accuracy: 0.8243 - val_precision: 0.8715 - val_recall: 0.7901 - val_f1_score: 0.8288
# Epoch 53/60
# 1248/1248 [==============================] - ETA: 0s - loss: 0.3723 - accuracy: 0.8688 - precision: 0.8974 - recall: 0.8430 - f1_score: 0.8694
# Epoch 53: val_accuracy improved from 0.82442 to 0.82632, saving model to models\modelo_S_sem_data_augmentation_adam_sem_reducelr_e_earlystopping.keras
# 1248/1248 [==============================] - 17s 13ms/step - loss: 0.3723 - accuracy: 0.8688 - precision: 0.8974 - recall: 0.8430 - f1_score: 0.8694 - val_loss: 0.5206 - val_accuracy: 0.8263 - val_precision: 0.8732 - val_recall: 0.7895 - val_f1_score: 0.8292
# Epoch 54/60
# 1247/1248 [============================>.] - ETA: 0s - loss: 0.3707 - accuracy: 0.8694 - precision: 0.8971 - recall: 0.8435 - f1_score: 0.8695
# Epoch 54: val_accuracy did not improve from 0.82632
# 1248/1248 [==============================] - 16s 13ms/step - loss: 0.3710 - accuracy: 0.8693 - precision: 0.8970 - recall: 0.8434 - f1_score: 0.8694 - val_loss: 0.6751 - val_accuracy: 0.7823 - val_precision: 0.8282 - val_recall: 0.7472 - val_f1_score: 0.7856
# Epoch 55/60
# 1244/1248 [============================>.] - ETA: 0s - loss: 0.3661 - accuracy: 0.8701 - precision: 0.8994 - recall: 0.8456 - f1_score: 0.8717
# Epoch 55: val_accuracy did not improve from 0.82632
# 1248/1248 [==============================] - 16s 13ms/step - loss: 0.3662 - accuracy: 0.8702 - precision: 0.8994 - recall: 0.8456 - f1_score: 0.8717 - val_loss: 0.7007 - val_accuracy: 0.7777 - val_precision: 0.8217 - val_recall: 0.7470 - val_f1_score: 0.7826
# Epoch 56/60
# 1245/1248 [============================>.] - ETA: 0s - loss: 0.3657 - accuracy: 0.8718 - precision: 0.8985 - recall: 0.8477 - f1_score: 0.8724
# Epoch 56: val_accuracy did not improve from 0.82632
# 1248/1248 [==============================] - 19s 15ms/step - loss: 0.3656 - accuracy: 0.8718 - precision: 0.8986 - recall: 0.8477 - f1_score: 0.8724 - val_loss: 0.8573 - val_accuracy: 0.7475 - val_precision: 0.7916 - val_recall: 0.7120 - val_f1_score: 0.7497
# Epoch 57/60
# 1248/1248 [==============================] - ETA: 0s - loss: 0.3619 - accuracy: 0.8731 - precision: 0.9003 - recall: 0.8491 - f1_score: 0.8740
# Epoch 57: val_accuracy improved from 0.82632 to 0.83273, saving model to models\modelo_S_sem_data_augmentation_adam_sem_reducelr_e_earlystopping.keras
# 1248/1248 [==============================] - 18s 14ms/step - loss: 0.3619 - accuracy: 0.8731 - precision: 0.9003 - recall: 0.8491 - f1_score: 0.8740 - val_loss: 0.5017 - val_accuracy: 0.8327 - val_precision: 0.8761 - val_recall: 0.7994 - val_f1_score: 0.8360
# Epoch 58/60
# 1247/1248 [============================>.] - ETA: 0s - loss: 0.3614 - accuracy: 0.8724 - precision: 0.8991 - recall: 0.8490 - f1_score: 0.8733
# Epoch 58: val_accuracy did not improve from 0.83273
# 1248/1248 [==============================] - 17s 14ms/step - loss: 0.3616 - accuracy: 0.8724 - precision: 0.8991 - recall: 0.8490 - f1_score: 0.8733 - val_loss: 0.7494 - val_accuracy: 0.7675 - val_precision: 0.8069 - val_recall: 0.7377 - val_f1_score: 0.7708
# Epoch 59/60
# 1245/1248 [============================>.] - ETA: 0s - loss: 0.3555 - accuracy: 0.8746 - precision: 0.8989 - recall: 0.8523 - f1_score: 0.8750
# Epoch 59: val_accuracy did not improve from 0.83273
# 1248/1248 [==============================] - 17s 13ms/step - loss: 0.3551 - accuracy: 0.8747 - precision: 0.8990 - recall: 0.8524 - f1_score: 0.8751 - val_loss: 0.5674 - val_accuracy: 0.8150 - val_precision: 0.8546 - val_recall: 0.7840 - val_f1_score: 0.8177
# Epoch 60/60
# 1243/1248 [============================>.] - ETA: 0s - loss: 0.3612 - accuracy: 0.8729 - precision: 0.8987 - recall: 0.8496 - f1_score: 0.8735
# Epoch 60: val_accuracy did not improve from 0.83273
# 1248/1248 [==============================] - 16s 13ms/step - loss: 0.3617 - accuracy: 0.8727 - precision: 0.8986 - recall: 0.8494 - f1_score: 0.8733 - val_loss: 0.6167 - val_accuracy: 0.8023 - val_precision: 0.8461 - val_recall: 0.7721 - val_f1_score: 0.8074
# 313/313 [==============================] - 6s 18ms/step - loss: 0.5853 - accuracy: 0.8078 - precision: 0.8536 - recall: 0.7784 - f1_score: 0.8143
# Test Loss: 0.5853438973426819
# Test Accuracy: 0.8077999949455261
# Test Precision: 0.8536023497581482
# Test Recall: 0.7784000039100647
# Test F1 Score: 0.8142684698104858

# %%
# Plot training history
plt.figure(figsize=(12, 8))
plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(history.history['val_precision'], label='val_precision')
plt.plot(history.history['val_recall'], label='val_recall')
plt.plot(history.history['val_f1_score'], label='val_f1_score')
plt.xlabel('Epoch')
plt.ylabel('Metrics')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.title('Validation Precision, Recall, F1 Score')

plt.tight_layout()
plt.savefig(f'./plots/modelo_S_sem_data_augmentation_adam_sem_reducelr_e_earlystopping.png')
plt.show()
