# %%
import json
import os
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.regularizers import l2
from tensorflow.keras.mixed_precision import set_global_policy

# %%
# MIX precision training -- facilita no treino!
set_global_policy('mixed_float16')

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# CONSTANTES
BATCH_SIZE = 64
IMG_SIZE = 150
NUM_CLASSES = 10  # nº classes para identificar
NUM_EPOCHS = 60  
LEARNING_RATE = 0.0001  
DENSE_LAYERS = [1024, 512, 256, 128]

# %%
# Folders do dataset
train_dirs = ['./dataset/train/train1', './dataset/train/train2',
              './dataset/train/train3', './dataset/train/train5']
validation_dir = './dataset/validation'
test_dir = './dataset/test'

# %%
# Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,  # Increase rotation range
    width_shift_range=0.1,  
    height_shift_range=0.1,  
    shear_range=0.1,  
    zoom_range=0.1,  
    horizontal_flip=True,
    vertical_flip=True,  # Adicionar flip vertical
    brightness_range=[0.6, 1.4],  # Adicionar range te brilho
    fill_mode='nearest')

validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# training generators
train_generators = [train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical') for train_dir in train_dirs]

# Necessário para juntar os trainning generators and repeat


def combined_generator(generators):
    while True:
        for generator in generators:
            for batch in generator:
                yield batch


train_generator = combined_generator(train_generators)

# Validation e test generators
validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical')

# load do modelo ResNet50 - deixar include_top=False 
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))

# Descongelar camadas (nao meter valores demasiado altos)
for layer in base_model.layers[-100:]:
    layer.trainable = True
# Out:
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.

# %%
from tensorflow.keras import backend as K
from tensorflow.keras.metrics import Metric

class Precision(Metric):
    def __init__(self, name='precision', **kwargs):
        super(Precision, self).__init__(name=name, **kwargs)
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.predicted_positives = self.add_weight(name='pp', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = K.round(y_pred)
        y_true = K.cast(y_true, 'float32')
        self.true_positives.assign_add(K.sum(y_true * y_pred))
        self.predicted_positives.assign_add(K.sum(y_pred))

    def result(self):
        return self.true_positives / (self.predicted_positives + K.epsilon())

    def reset_states(self):
        self.true_positives.assign(0)
        self.predicted_positives.assign(0)

class Recall(Metric):
    def __init__(self, name='recall', **kwargs):
        super(Recall, self).__init__(name=name, **kwargs)
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.actual_positives = self.add_weight(name='ap', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = K.round(y_pred)
        y_true = K.cast(y_true, 'float32')
        self.true_positives.assign_add(K.sum(y_true * y_pred))
        self.actual_positives.assign_add(K.sum(y_true))

    def result(self):
        return self.true_positives / (self.actual_positives + K.epsilon())

    def reset_states(self):
        self.true_positives.assign(0)
        self.actual_positives.assign(0)

class F1Score(Metric):
    def __init__(self, name='f1_score', **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.precision = Precision()
        self.recall = Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred)
        self.recall.update_state(y_true, y_pred)

    def result(self):
        precision = self.precision.result()
        recall = self.recall.result()
        return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

    def reset_states(self):
        self.precision.reset_states()
        self.recall.reset_states()

# %%
# Definir as layers do modelo com parametros ajustados para reduzir o overfitting
model = Sequential([
    base_model,
    BatchNormalization(),
    GlobalAveragePooling2D(),
    # Increase model complexity
    Dense(DENSE_LAYERS[0], activation='relu', kernel_regularizer=l2(0.03)),
    Dropout(0.5),  # High dropout rate for regularization
    BatchNormalization(),
    Dense(DENSE_LAYERS[1], activation='relu', kernel_regularizer=l2(0.03)),
    Dropout(0.5),
    BatchNormalization(),
    Dense(DENSE_LAYERS[2], activation='relu', kernel_regularizer=l2(0.03)),
    Dropout(0.5),
    Dense(DENSE_LAYERS[3], activation='relu', kernel_regularizer=l2(0.03)),
    Dropout(0.5),
    BatchNormalization(),
    Dense(NUM_CLASSES, activation='softmax', dtype='float32')
])

# Compilar o modelo
model.compile(optimizer=Adam(learning_rate=LEARNING_RATE),
              loss='categorical_crossentropy',
              metrics=['accuracy', Precision(), Recall(), F1Score()])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 5, 5, 2048)        23587712
#
#  batch_normalization (BatchN  (None, 5, 5, 2048)       8192
#  ormalization)
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dropout (Dropout)           (None, 1024)              0
#
#  batch_normalization_1 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  batch_normalization_2 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_4 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 26,391,050
# Trainable params: 26,330,506
# Non-trainable params: 60,544
# _________________________________________________________________

# %%
# CALLBACKS
os.makedirs('logs', exist_ok=True)
checkpoint = ModelCheckpoint(f'models/modelo_T_com_data_augmentation_adam.keras',
                             monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early_stopping = EarlyStopping(
    monitor='val_loss', patience=10, restore_best_weights=True)  # Increased patience
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=4, min_lr=1e-7, verbose=1)  # More aggressive schedule
csv_logger = CSVLogger(
    f'logs/modelo_T_com_data_augmentation_adam.csv', separator=',', append=False)

# calcular passos por epoch
steps_per_epoch = sum([gen.samples // BATCH_SIZE for gen in train_generators])
validation_steps = validation_generator.samples // BATCH_SIZE

# %%
# calcular passos por epoch
# Treinar o modelo - Nao tirar os callbacks
history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=NUM_EPOCHS,
    validation_data=validation_generator,
    validation_steps=validation_steps,
    callbacks=[checkpoint, early_stopping, reduce_lr, csv_logger]
)

# Avaliar o modelo no test generator
# Avaliar o modelo no test generator
results = model.evaluate(test_generator)
loss, accuracy, precision, recall, f1_score = results[:5]
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
print(f"Test Precision: {precision}")
print(f"Test Recall: {recall}")
print(f"Test F1 Score: {f1_score}")
# Out:
# Epoch 1/60
# 624/624 [==============================] - ETA: 0s - loss: 54.1377 - accuracy: 0.2736 - precision: 0.4342 - recall: 0.1219 - f1_score: 0.1903
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric Precision implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric Recall implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# Epoch 1: val_accuracy improved from -inf to 0.10647, saving model to models\modelo_T_com_data_augmentation_adam.keras
# 624/624 [==============================] - 184s 272ms/step - loss: 54.1377 - accuracy: 0.2736 - precision: 0.4342 - recall: 0.1219 - f1_score: 0.1903 - val_loss: 34.5805 - val_accuracy: 0.1065 - val_precision: 0.2625 - val_recall: 0.0751 - val_f1_score: 0.1168 - lr: 1.0000e-04
# Epoch 2/60
# 624/624 [==============================] - ETA: 0s - loss: 20.7348 - accuracy: 0.6656 - precision: 0.7946 - recall: 0.5115 - f1_score: 0.6224
# Epoch 2: val_accuracy improved from 0.10647 to 0.80859, saving model to models\modelo_T_com_data_augmentation_adam.keras
# 624/624 [==============================] - 162s 260ms/step - loss: 20.7348 - accuracy: 0.6656 - precision: 0.7946 - recall: 0.5115 - f1_score: 0.6224 - val_loss: 11.3277 - val_accuracy: 0.8086 - val_precision: 0.9032 - val_recall: 0.7100 - val_f1_score: 0.7950 - lr: 1.0000e-04
# Epoch 3/60
# 624/624 [==============================] - ETA: 0s - loss: 6.9029 - accuracy: 0.8225 - precision: 0.8861 - recall: 0.7463 - f1_score: 0.8102
# Epoch 3: val_accuracy improved from 0.80859 to 0.84545, saving model to models\modelo_T_com_data_augmentation_adam.keras
# 624/624 [==============================] - 162s 259ms/step - loss: 6.9029 - accuracy: 0.8225 - precision: 0.8861 - recall: 0.7463 - f1_score: 0.8102 - val_loss: 3.8367 - val_accuracy: 0.8455 - val_precision: 0.9026 - val_recall: 0.7784 - val_f1_score: 0.8359 - lr: 1.0000e-04
# Epoch 4/60
# 624/624 [==============================] - ETA: 0s - loss: 2.5176 - accuracy: 0.8678 - precision: 0.9085 - recall: 0.8210 - f1_score: 0.8625
# Epoch 4: val_accuracy did not improve from 0.84545
# 624/624 [==============================] - 161s 258ms/step - loss: 2.5176 - accuracy: 0.8678 - precision: 0.9085 - recall: 0.8210 - f1_score: 0.8625 - val_loss: 1.7169 - val_accuracy: 0.8405 - val_precision: 0.8868 - val_recall: 0.8023 - val_f1_score: 0.8424 - lr: 1.0000e-04
# Epoch 5/60
# 624/624 [==============================] - ETA: 0s - loss: 1.2132 - accuracy: 0.8922 - precision: 0.9211 - recall: 0.8602 - f1_score: 0.8896
# Epoch 5: val_accuracy improved from 0.84545 to 0.85026, saving model to models\modelo_T_com_data_augmentation_adam.keras
# 624/624 [==============================] - 162s 259ms/step - loss: 1.2132 - accuracy: 0.8922 - precision: 0.9211 - recall: 0.8602 - f1_score: 0.8896 - val_loss: 1.0436 - val_accuracy: 0.8503 - val_precision: 0.8748 - val_recall: 0.8339 - val_f1_score: 0.8539 - lr: 1.0000e-04
# Epoch 6/60
# 624/624 [==============================] - ETA: 0s - loss: 0.7635 - accuracy: 0.9089 - precision: 0.9307 - recall: 0.8864 - f1_score: 0.9080
# Epoch 6: val_accuracy improved from 0.85026 to 0.85236, saving model to models\modelo_T_com_data_augmentation_adam.keras
# 624/624 [==============================] - 161s 259ms/step - loss: 0.7635 - accuracy: 0.9089 - precision: 0.9307 - recall: 0.8864 - f1_score: 0.9080 - val_loss: 0.8075 - val_accuracy: 0.8524 - val_precision: 0.8800 - val_recall: 0.8321 - val_f1_score: 0.8554 - lr: 1.0000e-04
# Epoch 7/60
# 624/624 [==============================] - ETA: 0s - loss: 0.5860 - accuracy: 0.9209 - precision: 0.9391 - recall: 0.9025 - f1_score: 0.9204
# Epoch 7: val_accuracy improved from 0.85236 to 0.86649, saving model to models\modelo_T_com_data_augmentation_adam.keras
# 624/624 [==============================] - 162s 260ms/step - loss: 0.5860 - accuracy: 0.9209 - precision: 0.9391 - recall: 0.9025 - f1_score: 0.9204 - val_loss: 0.7053 - val_accuracy: 0.8665 - val_precision: 0.8846 - val_recall: 0.8530 - val_f1_score: 0.8685 - lr: 1.0000e-04
# Epoch 8/60
# 624/624 [==============================] - ETA: 0s - loss: 0.5054 - accuracy: 0.9283 - precision: 0.9436 - recall: 0.9132 - f1_score: 0.9282
# Epoch 8: val_accuracy did not improve from 0.86649
# 624/624 [==============================] - 167s 268ms/step - loss: 0.5054 - accuracy: 0.9283 - precision: 0.9436 - recall: 0.9132 - f1_score: 0.9282 - val_loss: 0.7176 - val_accuracy: 0.8583 - val_precision: 0.8794 - val_recall: 0.8445 - val_f1_score: 0.8616 - lr: 1.0000e-04
# Epoch 9/60
# 624/624 [==============================] - ETA: 0s - loss: 0.4526 - accuracy: 0.9350 - precision: 0.9479 - recall: 0.9224 - f1_score: 0.9350
# Epoch 9: val_accuracy did not improve from 0.86649
# 624/624 [==============================] - 188s 302ms/step - loss: 0.4526 - accuracy: 0.9350 - precision: 0.9479 - recall: 0.9224 - f1_score: 0.9350 - val_loss: 0.7067 - val_accuracy: 0.8651 - val_precision: 0.8821 - val_recall: 0.8537 - val_f1_score: 0.8677 - lr: 1.0000e-04
# Epoch 10/60
# 624/624 [==============================] - ETA: 0s - loss: 0.4318 - accuracy: 0.9380 - precision: 0.9507 - recall: 0.9266 - f1_score: 0.9385
# Epoch 10: val_accuracy did not improve from 0.86649
# 624/624 [==============================] - 188s 302ms/step - loss: 0.4318 - accuracy: 0.9380 - precision: 0.9507 - recall: 0.9266 - f1_score: 0.9385 - val_loss: 0.7266 - val_accuracy: 0.8561 - val_precision: 0.8697 - val_recall: 0.8467 - val_f1_score: 0.8580 - lr: 1.0000e-04
# Epoch 11/60
# 624/624 [==============================] - ETA: 0s - loss: 0.4053 - accuracy: 0.9428 - precision: 0.9537 - recall: 0.9330 - f1_score: 0.9432
# Epoch 11: val_accuracy improved from 0.86649 to 0.87450, saving model to models\modelo_T_com_data_augmentation_adam.keras
# 624/624 [==============================] - 191s 307ms/step - loss: 0.4053 - accuracy: 0.9428 - precision: 0.9537 - recall: 0.9330 - f1_score: 0.9432 - val_loss: 0.6386 - val_accuracy: 0.8745 - val_precision: 0.8885 - val_recall: 0.8630 - val_f1_score: 0.8756 - lr: 1.0000e-04
# Epoch 12/60
# 624/624 [==============================] - ETA: 0s - loss: 0.4058 - accuracy: 0.9437 - precision: 0.9541 - recall: 0.9327 - f1_score: 0.9433
# Epoch 12: val_accuracy did not improve from 0.87450
# 624/624 [==============================] - 167s 267ms/step - loss: 0.4058 - accuracy: 0.9437 - precision: 0.9541 - recall: 0.9327 - f1_score: 0.9433 - val_loss: 0.9457 - val_accuracy: 0.8217 - val_precision: 0.8339 - val_recall: 0.8140 - val_f1_score: 0.8238 - lr: 1.0000e-04
# Epoch 13/60
# 624/624 [==============================] - ETA: 0s - loss: 0.3749 - accuracy: 0.9510 - precision: 0.9590 - recall: 0.9424 - f1_score: 0.9506
# Epoch 13: val_accuracy did not improve from 0.87450
# 624/624 [==============================] - 171s 274ms/step - loss: 0.3749 - accuracy: 0.9510 - precision: 0.9590 - recall: 0.9424 - f1_score: 0.9506 - val_loss: 0.8413 - val_accuracy: 0.8479 - val_precision: 0.8599 - val_recall: 0.8397 - val_f1_score: 0.8497 - lr: 1.0000e-04
# Epoch 14/60
# 624/624 [==============================] - ETA: 0s - loss: 0.3601 - accuracy: 0.9543 - precision: 0.9618 - recall: 0.9464 - f1_score: 0.9541
# Epoch 14: val_accuracy did not improve from 0.87450
# 624/624 [==============================] - 172s 276ms/step - loss: 0.3601 - accuracy: 0.9543 - precision: 0.9618 - recall: 0.9464 - f1_score: 0.9541 - val_loss: 0.7454 - val_accuracy: 0.8580 - val_precision: 0.8706 - val_recall: 0.8501 - val_f1_score: 0.8602 - lr: 1.0000e-04
# Epoch 15/60
# 624/624 [==============================] - ETA: 0s - loss: 0.3560 - accuracy: 0.9557 - precision: 0.9627 - recall: 0.9484 - f1_score: 0.9555
# Epoch 15: val_accuracy did not improve from 0.87450
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 624/624 [==============================] - 173s 277ms/step - loss: 0.3560 - accuracy: 0.9557 - precision: 0.9627 - recall: 0.9484 - f1_score: 0.9555 - val_loss: 0.7287 - val_accuracy: 0.8634 - val_precision: 0.8740 - val_recall: 0.8564 - val_f1_score: 0.8651 - lr: 1.0000e-04
# Epoch 16/60
# 624/624 [==============================] - ETA: 0s - loss: 0.2262 - accuracy: 0.9789 - precision: 0.9819 - recall: 0.9752 - f1_score: 0.9785
# Epoch 16: val_accuracy improved from 0.87450 to 0.90234, saving model to models\modelo_T_com_data_augmentation_adam.keras
# 624/624 [==============================] - 174s 279ms/step - loss: 0.2262 - accuracy: 0.9789 - precision: 0.9819 - recall: 0.9752 - f1_score: 0.9785 - val_loss: 0.5183 - val_accuracy: 0.9023 - val_precision: 0.9082 - val_recall: 0.8985 - val_f1_score: 0.9033 - lr: 2.0000e-05
# Epoch 17/60
# 624/624 [==============================] - ETA: 0s - loss: 0.1555 - accuracy: 0.9870 - precision: 0.9887 - recall: 0.9849 - f1_score: 0.9868
# Epoch 17: val_accuracy improved from 0.90234 to 0.90675, saving model to models\modelo_T_com_data_augmentation_adam.keras
# 624/624 [==============================] - 175s 280ms/step - loss: 0.1555 - accuracy: 0.9870 - precision: 0.9887 - recall: 0.9849 - f1_score: 0.9868 - val_loss: 0.4868 - val_accuracy: 0.9068 - val_precision: 0.9122 - val_recall: 0.9036 - val_f1_score: 0.9079 - lr: 2.0000e-05
# Epoch 18/60
# 624/624 [==============================] - ETA: 0s - loss: 0.1273 - accuracy: 0.9894 - precision: 0.9912 - recall: 0.9880 - f1_score: 0.9896
# Epoch 18: val_accuracy improved from 0.90675 to 0.90815, saving model to models\modelo_T_com_data_augmentation_adam.keras
# 624/624 [==============================] - 174s 279ms/step - loss: 0.1273 - accuracy: 0.9894 - precision: 0.9912 - recall: 0.9880 - f1_score: 0.9896 - val_loss: 0.4869 - val_accuracy: 0.9082 - val_precision: 0.9128 - val_recall: 0.9056 - val_f1_score: 0.9092 - lr: 2.0000e-05
# Epoch 19/60
# 624/624 [==============================] - ETA: 0s - loss: 0.1147 - accuracy: 0.9900 - precision: 0.9913 - recall: 0.9888 - f1_score: 0.9900
# Epoch 19: val_accuracy did not improve from 0.90815
# 624/624 [==============================] - 172s 276ms/step - loss: 0.1147 - accuracy: 0.9900 - precision: 0.9913 - recall: 0.9888 - f1_score: 0.9900 - val_loss: 0.4936 - val_accuracy: 0.9061 - val_precision: 0.9105 - val_recall: 0.9038 - val_f1_score: 0.9072 - lr: 2.0000e-05
# Epoch 20/60
# 624/624 [==============================] - ETA: 0s - loss: 0.1049 - accuracy: 0.9909 - precision: 0.9924 - recall: 0.9897 - f1_score: 0.9911
# Epoch 20: val_accuracy did not improve from 0.90815
# 624/624 [==============================] - 173s 278ms/step - loss: 0.1049 - accuracy: 0.9909 - precision: 0.9924 - recall: 0.9897 - f1_score: 0.9911 - val_loss: 0.5245 - val_accuracy: 0.9043 - val_precision: 0.9080 - val_recall: 0.9026 - val_f1_score: 0.9053 - lr: 2.0000e-05
# Epoch 21/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0982 - accuracy: 0.9916 - precision: 0.9928 - recall: 0.9906 - f1_score: 0.9917
# Epoch 21: val_accuracy did not improve from 0.90815
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 624/624 [==============================] - 162s 260ms/step - loss: 0.0982 - accuracy: 0.9916 - precision: 0.9928 - recall: 0.9906 - f1_score: 0.9917 - val_loss: 0.5369 - val_accuracy: 0.9039 - val_precision: 0.9075 - val_recall: 0.9018 - val_f1_score: 0.9047 - lr: 2.0000e-05
# Epoch 22/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9940 - precision: 0.9946 - recall: 0.9931 - f1_score: 0.9938
# Epoch 22: val_accuracy improved from 0.90815 to 0.91246, saving model to models\modelo_T_com_data_augmentation_adam.keras
# 624/624 [==============================] - 164s 262ms/step - loss: 0.0862 - accuracy: 0.9940 - precision: 0.9946 - recall: 0.9931 - f1_score: 0.9938 - val_loss: 0.4675 - val_accuracy: 0.9125 - val_precision: 0.9162 - val_recall: 0.9110 - val_f1_score: 0.9136 - lr: 4.0000e-06
# Epoch 23/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0752 - accuracy: 0.9951 - precision: 0.9957 - recall: 0.9946 - f1_score: 0.9952
# Epoch 23: val_accuracy improved from 0.91246 to 0.91416, saving model to models\modelo_T_com_data_augmentation_adam.keras
# 624/624 [==============================] - 163s 262ms/step - loss: 0.0752 - accuracy: 0.9951 - precision: 0.9957 - recall: 0.9946 - f1_score: 0.9952 - val_loss: 0.4648 - val_accuracy: 0.9142 - val_precision: 0.9184 - val_recall: 0.9126 - val_f1_score: 0.9155 - lr: 4.0000e-06
# Epoch 24/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0692 - accuracy: 0.9962 - precision: 0.9967 - recall: 0.9957 - f1_score: 0.9962
# Epoch 24: val_accuracy did not improve from 0.91416
# 624/624 [==============================] - 164s 264ms/step - loss: 0.0692 - accuracy: 0.9962 - precision: 0.9967 - recall: 0.9957 - f1_score: 0.9962 - val_loss: 0.4643 - val_accuracy: 0.9142 - val_precision: 0.9179 - val_recall: 0.9121 - val_f1_score: 0.9149 - lr: 4.0000e-06
# Epoch 25/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0647 - accuracy: 0.9967 - precision: 0.9971 - recall: 0.9962 - f1_score: 0.9966
# Epoch 25: val_accuracy did not improve from 0.91416
# 624/624 [==============================] - 164s 263ms/step - loss: 0.0647 - accuracy: 0.9967 - precision: 0.9971 - recall: 0.9962 - f1_score: 0.9966 - val_loss: 0.4694 - val_accuracy: 0.9134 - val_precision: 0.9160 - val_recall: 0.9117 - val_f1_score: 0.9138 - lr: 4.0000e-06
# Epoch 26/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0619 - accuracy: 0.9966 - precision: 0.9969 - recall: 0.9960 - f1_score: 0.9965
# Epoch 26: val_accuracy did not improve from 0.91416
# 624/624 [==============================] - 166s 266ms/step - loss: 0.0619 - accuracy: 0.9966 - precision: 0.9969 - recall: 0.9960 - f1_score: 0.9965 - val_loss: 0.4723 - val_accuracy: 0.9140 - val_precision: 0.9169 - val_recall: 0.9125 - val_f1_score: 0.9147 - lr: 4.0000e-06
# Epoch 27/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0595 - accuracy: 0.9966 - precision: 0.9972 - recall: 0.9963 - f1_score: 0.9967
# Epoch 27: val_accuracy did not improve from 0.91416
# 624/624 [==============================] - 170s 273ms/step - loss: 0.0595 - accuracy: 0.9966 - precision: 0.9972 - recall: 0.9963 - f1_score: 0.9967 - val_loss: 0.4717 - val_accuracy: 0.9126 - val_precision: 0.9151 - val_recall: 0.9104 - val_f1_score: 0.9127 - lr: 4.0000e-06
# Epoch 28/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0564 - accuracy: 0.9969 - precision: 0.9973 - recall: 0.9963 - f1_score: 0.9968
# Epoch 28: val_accuracy improved from 0.91416 to 0.91466, saving model to models\modelo_T_com_data_augmentation_adam.keras
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 624/624 [==============================] - 169s 271ms/step - loss: 0.0564 - accuracy: 0.9969 - precision: 0.9973 - recall: 0.9963 - f1_score: 0.9968 - val_loss: 0.4724 - val_accuracy: 0.9147 - val_precision: 0.9167 - val_recall: 0.9134 - val_f1_score: 0.9150 - lr: 4.0000e-06
# Epoch 29/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0543 - accuracy: 0.9974 - precision: 0.9976 - recall: 0.9969 - f1_score: 0.9973
# Epoch 29: val_accuracy did not improve from 0.91466
# 624/624 [==============================] - 169s 272ms/step - loss: 0.0543 - accuracy: 0.9974 - precision: 0.9976 - recall: 0.9969 - f1_score: 0.9973 - val_loss: 0.4740 - val_accuracy: 0.9147 - val_precision: 0.9172 - val_recall: 0.9136 - val_f1_score: 0.9154 - lr: 8.0000e-07
# Epoch 30/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0537 - accuracy: 0.9974 - precision: 0.9978 - recall: 0.9970 - f1_score: 0.9974
# Epoch 30: val_accuracy did not improve from 0.91466
# 624/624 [==============================] - 167s 267ms/step - loss: 0.0537 - accuracy: 0.9974 - precision: 0.9978 - recall: 0.9970 - f1_score: 0.9974 - val_loss: 0.4711 - val_accuracy: 0.9136 - val_precision: 0.9169 - val_recall: 0.9127 - val_f1_score: 0.9148 - lr: 8.0000e-07
# Epoch 31/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0530 - accuracy: 0.9975 - precision: 0.9978 - recall: 0.9970 - f1_score: 0.9974
# Epoch 31: val_accuracy did not improve from 0.91466
# 624/624 [==============================] - 164s 263ms/step - loss: 0.0530 - accuracy: 0.9975 - precision: 0.9978 - recall: 0.9970 - f1_score: 0.9974 - val_loss: 0.4731 - val_accuracy: 0.9144 - val_precision: 0.9175 - val_recall: 0.9129 - val_f1_score: 0.9152 - lr: 8.0000e-07
# Epoch 32/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0514 - accuracy: 0.9975 - precision: 0.9978 - recall: 0.9971 - f1_score: 0.9974
# Epoch 32: val_accuracy did not improve from 0.91466
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# 624/624 [==============================] - 163s 261ms/step - loss: 0.0514 - accuracy: 0.9975 - precision: 0.9978 - recall: 0.9971 - f1_score: 0.9974 - val_loss: 0.4713 - val_accuracy: 0.9145 - val_precision: 0.9170 - val_recall: 0.9134 - val_f1_score: 0.9152 - lr: 8.0000e-07
# Epoch 33/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0529 - accuracy: 0.9972 - precision: 0.9976 - recall: 0.9968 - f1_score: 0.9972
# Epoch 33: val_accuracy improved from 0.91466 to 0.91486, saving model to models\modelo_T_com_data_augmentation_adam.keras
# 624/624 [==============================] - 169s 271ms/step - loss: 0.0529 - accuracy: 0.9972 - precision: 0.9976 - recall: 0.9968 - f1_score: 0.9972 - val_loss: 0.4724 - val_accuracy: 0.9149 - val_precision: 0.9171 - val_recall: 0.9136 - val_f1_score: 0.9153 - lr: 1.6000e-07
# Epoch 34/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0515 - accuracy: 0.9976 - precision: 0.9979 - recall: 0.9971 - f1_score: 0.9975
# Epoch 34: val_accuracy did not improve from 0.91486
# 624/624 [==============================] - 176s 282ms/step - loss: 0.0515 - accuracy: 0.9976 - precision: 0.9979 - recall: 0.9971 - f1_score: 0.9975 - val_loss: 0.4719 - val_accuracy: 0.9141 - val_precision: 0.9165 - val_recall: 0.9129 - val_f1_score: 0.9147 - lr: 1.6000e-07
# 157/157 [==============================] - 9s 57ms/step - loss: 0.4807 - accuracy: 0.9125 - precision: 0.9150 - recall: 0.9111 - f1_score: 0.9131
# Test Loss: 0.4807491600513458
# Test Accuracy: 0.9125000238418579
# Test Precision: 0.9150346517562866
# Test Recall: 0.9110999703407288
# Test F1 Score: 0.9130629897117615

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(history.history['val_precision'], label='val_precision')
plt.plot(history.history['val_recall'], label='val_recall')
plt.plot(history.history['val_f1_score'], label='val_f1_score')
plt.xlabel('Epoch')
plt.ylabel('Metrics')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.title('Validation Precision, Recall, F1 Score')

plt.savefig(f'./plots/modelo_T_com_data_augmentation_adam.png')
plt.tight_layout()
#plt.show()
