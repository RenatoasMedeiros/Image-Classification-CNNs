# %%
import json
import os
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.regularizers import l2
from tensorflow.keras.mixed_precision import set_global_policy

# %%
# MIX precision training -- facilita no treino!
set_global_policy('mixed_float16')

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# CONSTANTES
BATCH_SIZE = 64
IMG_SIZE = 150
NUM_CLASSES = 10  # nº classes para identificar
NUM_EPOCHS = 60  
LEARNING_RATE = 0.0001  
DENSE_LAYERS = [1024, 512, 256, 128]
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 4070, compute capability 8.9

# %%
# Folders do dataset
train_dirs = ['./dataset/train/train1', './dataset/train/train2',
              './dataset/train/train3', './dataset/train/train5']
validation_dir = './dataset/validation'
test_dir = './dataset/test'

# %%
# Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,  # Increase rotation range
    width_shift_range=0.1,  
    height_shift_range=0.1,  
    shear_range=0.1,  
    zoom_range=0.1,  
    horizontal_flip=True,
    vertical_flip=True,  # Adicionar flip vertical
    brightness_range=[0.6, 1.4],  # Adicionar range te brilho
    fill_mode='nearest')

validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# training generators
train_generators = [train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical') for train_dir in train_dirs]

# Necessário para juntar os trainning generators and repeat


def combined_generator(generators):
    while True:
        for generator in generators:
            for batch in generator:
                yield batch


train_generator = combined_generator(train_generators)

# Validation e test generators
validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical')

# load do modelo ResNet50 - deixar include_top=False 
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))

# Descongelar camadas (nao meter valores demasiado altos)
for layer in base_model.layers[-100:]:
    layer.trainable = True
# Out:
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.

# %%
from tensorflow.keras import backend as K
from tensorflow.keras.metrics import Metric

class Precision(Metric):
    def __init__(self, name='precision', **kwargs):
        super(Precision, self).__init__(name=name, **kwargs)
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.predicted_positives = self.add_weight(name='pp', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = K.round(y_pred)
        y_true = K.cast(y_true, 'float32')
        self.true_positives.assign_add(K.sum(y_true * y_pred))
        self.predicted_positives.assign_add(K.sum(y_pred))

    def result(self):
        return self.true_positives / (self.predicted_positives + K.epsilon())

    def reset_states(self):
        self.true_positives.assign(0)
        self.predicted_positives.assign(0)

class Recall(Metric):
    def __init__(self, name='recall', **kwargs):
        super(Recall, self).__init__(name=name, **kwargs)
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.actual_positives = self.add_weight(name='ap', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = K.round(y_pred)
        y_true = K.cast(y_true, 'float32')
        self.true_positives.assign_add(K.sum(y_true * y_pred))
        self.actual_positives.assign_add(K.sum(y_true))

    def result(self):
        return self.true_positives / (self.actual_positives + K.epsilon())

    def reset_states(self):
        self.true_positives.assign(0)
        self.actual_positives.assign(0)

class F1Score(Metric):
    def __init__(self, name='f1_score', **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.precision = Precision()
        self.recall = Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred)
        self.recall.update_state(y_true, y_pred)

    def result(self):
        precision = self.precision.result()
        recall = self.recall.result()
        return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

    def reset_states(self):
        self.precision.reset_states()
        self.recall.reset_states()

# %%
# Definir as layers do modelo com parametros ajustados para reduzir o overfitting
model = Sequential([
    base_model,
    BatchNormalization(),
    GlobalAveragePooling2D(),
    # Increase model complexity
    Dense(DENSE_LAYERS[0], activation='relu', kernel_regularizer=l2(0.03)),
    Dropout(0.5),  # High dropout rate for regularization
    BatchNormalization(),
    Dense(DENSE_LAYERS[1], activation='relu', kernel_regularizer=l2(0.03)),
    Dropout(0.5),
    BatchNormalization(),
    Dense(DENSE_LAYERS[2], activation='relu', kernel_regularizer=l2(0.03)),
    Dropout(0.5),
    Dense(DENSE_LAYERS[3], activation='relu', kernel_regularizer=l2(0.03)),
    Dropout(0.5),
    BatchNormalization(),
    Dense(NUM_CLASSES, activation='softmax', dtype='float32')
])

# Compilar o modelo
model.compile(optimizer=RMSprop(learning_rate=LEARNING_RATE),
              loss='categorical_crossentropy',
              metrics=['accuracy', Precision(), Recall(), F1Score()])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 5, 5, 2048)        23587712
#
#  batch_normalization (BatchN  (None, 5, 5, 2048)       8192
#  ormalization)
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dropout (Dropout)           (None, 1024)              0
#
#  batch_normalization_1 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  batch_normalization_2 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_4 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 26,391,050
# Trainable params: 26,330,506
# Non-trainable params: 60,544
# _________________________________________________________________

# %%
# CALLBACKS
os.makedirs('logs', exist_ok=True)
checkpoint = ModelCheckpoint(f'models/modelo_T_com_data_augmentation_rmsprop.keras',
                             monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early_stopping = EarlyStopping(
    monitor='val_loss', patience=10, restore_best_weights=True)  # Increased patience
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=4, min_lr=1e-7, verbose=1)  # More aggressive schedule
csv_logger = CSVLogger(
    f'logs/modelo_T_com_data_augmentation_rmsprop.csv', separator=',', append=False)

# calcular passos por epoch
steps_per_epoch = sum([gen.samples // BATCH_SIZE for gen in train_generators])
validation_steps = validation_generator.samples // BATCH_SIZE

# %%
# calcular passos por epoch
# Treinar o modelo - Nao tirar os callbacks
history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=NUM_EPOCHS,
    validation_data=validation_generator,
    validation_steps=validation_steps,
    callbacks=[checkpoint, early_stopping, reduce_lr, csv_logger]
)

# Avaliar o modelo no test generator
# Avaliar o modelo no test generator
results = model.evaluate(test_generator)
loss, accuracy, precision, recall, f1_score = results[:5]
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
print(f"Test Precision: {precision}")
print(f"Test Recall: {recall}")
print(f"Test F1 Score: {f1_score}")
# Out:
# Epoch 1/60
# 624/624 [==============================] - ETA: 0s - loss: 50.2692 - accuracy: 0.3121 - precision: 0.5344 - recall: 0.1509 - f1_score: 0.2354
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric Precision implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric Recall implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# Epoch 1: val_accuracy improved from -inf to 0.15445, saving model to models\modelo_T_com_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 188s 272ms/step - loss: 50.2692 - accuracy: 0.3121 - precision: 0.5344 - recall: 0.1509 - f1_score: 0.2354 - val_loss: 24.9409 - val_accuracy: 0.1544 - val_precision: 0.6600 - val_recall: 0.0033 - val_f1_score: 0.0066 - lr: 1.0000e-04
# Epoch 2/60
# 624/624 [==============================] - ETA: 0s - loss: 11.4174 - accuracy: 0.7191 - precision: 0.8384 - recall: 0.5783 - f1_score: 0.6845
# Epoch 2: val_accuracy improved from 0.15445 to 0.79157, saving model to models\modelo_T_com_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 170s 272ms/step - loss: 11.4174 - accuracy: 0.7191 - precision: 0.8384 - recall: 0.5783 - f1_score: 0.6845 - val_loss: 4.7108 - val_accuracy: 0.7916 - val_precision: 0.8482 - val_recall: 0.7240 - val_f1_score: 0.7812 - lr: 1.0000e-04
# Epoch 3/60
# 624/624 [==============================] - ETA: 0s - loss: 2.7251 - accuracy: 0.8347 - precision: 0.8894 - recall: 0.7713 - f1_score: 0.8261
# Epoch 3: val_accuracy improved from 0.79157 to 0.82512, saving model to models\modelo_T_com_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 166s 266ms/step - loss: 2.7251 - accuracy: 0.8347 - precision: 0.8894 - recall: 0.7713 - f1_score: 0.8261 - val_loss: 1.7072 - val_accuracy: 0.8251 - val_precision: 0.8558 - val_recall: 0.8003 - val_f1_score: 0.8271 - lr: 1.0000e-04
# Epoch 4/60
# 624/624 [==============================] - ETA: 0s - loss: 1.1487 - accuracy: 0.8756 - precision: 0.9128 - recall: 0.8357 - f1_score: 0.8726
# Epoch 4: val_accuracy improved from 0.82512 to 0.83163, saving model to models\modelo_T_com_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 166s 266ms/step - loss: 1.1487 - accuracy: 0.8756 - precision: 0.9128 - recall: 0.8357 - f1_score: 0.8726 - val_loss: 1.0496 - val_accuracy: 0.8316 - val_precision: 0.8592 - val_recall: 0.8089 - val_f1_score: 0.8333 - lr: 1.0000e-04
# Epoch 5/60
# 624/624 [==============================] - ETA: 0s - loss: 0.7320 - accuracy: 0.8950 - precision: 0.9237 - recall: 0.8659 - f1_score: 0.8939
# Epoch 5: val_accuracy improved from 0.83163 to 0.84986, saving model to models\modelo_T_com_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 166s 266ms/step - loss: 0.7320 - accuracy: 0.8950 - precision: 0.9237 - recall: 0.8659 - f1_score: 0.8939 - val_loss: 0.8392 - val_accuracy: 0.8499 - val_precision: 0.8740 - val_recall: 0.8317 - val_f1_score: 0.8523 - lr: 1.0000e-04
# Epoch 6/60
# 624/624 [==============================] - ETA: 0s - loss: 0.5702 - accuracy: 0.9128 - precision: 0.9332 - recall: 0.8891 - f1_score: 0.9106
# Epoch 6: val_accuracy improved from 0.84986 to 0.87520, saving model to models\modelo_T_com_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 164s 264ms/step - loss: 0.5702 - accuracy: 0.9128 - precision: 0.9332 - recall: 0.8891 - f1_score: 0.9106 - val_loss: 0.6756 - val_accuracy: 0.8752 - val_precision: 0.8951 - val_recall: 0.8595 - val_f1_score: 0.8769 - lr: 1.0000e-04
# Epoch 7/60
# 624/624 [==============================] - ETA: 0s - loss: 0.4859 - accuracy: 0.9211 - precision: 0.9392 - recall: 0.9029 - f1_score: 0.9207
# Epoch 7: val_accuracy did not improve from 0.87520
# 624/624 [==============================] - 166s 266ms/step - loss: 0.4859 - accuracy: 0.9211 - precision: 0.9392 - recall: 0.9029 - f1_score: 0.9207 - val_loss: 0.9030 - val_accuracy: 0.8348 - val_precision: 0.8525 - val_recall: 0.8217 - val_f1_score: 0.8368 - lr: 1.0000e-04
# Epoch 8/60
# 624/624 [==============================] - ETA: 0s - loss: 0.4416 - accuracy: 0.9293 - precision: 0.9449 - recall: 0.9138 - f1_score: 0.9291
# Epoch 8: val_accuracy did not improve from 0.87520
# 624/624 [==============================] - 165s 264ms/step - loss: 0.4416 - accuracy: 0.9293 - precision: 0.9449 - recall: 0.9138 - f1_score: 0.9291 - val_loss: 0.6738 - val_accuracy: 0.8733 - val_precision: 0.8877 - val_recall: 0.8639 - val_f1_score: 0.8756 - lr: 1.0000e-04
# Epoch 9/60
# 624/624 [==============================] - ETA: 0s - loss: 0.4111 - accuracy: 0.9354 - precision: 0.9497 - recall: 0.9207 - f1_score: 0.9350
# Epoch 9: val_accuracy did not improve from 0.87520
# 624/624 [==============================] - 165s 265ms/step - loss: 0.4111 - accuracy: 0.9354 - precision: 0.9497 - recall: 0.9207 - f1_score: 0.9350 - val_loss: 0.6898 - val_accuracy: 0.8744 - val_precision: 0.8844 - val_recall: 0.8668 - val_f1_score: 0.8755 - lr: 1.0000e-04
# Epoch 10/60
# 624/624 [==============================] - ETA: 0s - loss: 0.3771 - accuracy: 0.9427 - precision: 0.9542 - recall: 0.9305 - f1_score: 0.9422
# Epoch 10: val_accuracy did not improve from 0.87520
# 624/624 [==============================] - 164s 264ms/step - loss: 0.3771 - accuracy: 0.9427 - precision: 0.9542 - recall: 0.9305 - f1_score: 0.9422 - val_loss: 0.7167 - val_accuracy: 0.8688 - val_precision: 0.8820 - val_recall: 0.8610 - val_f1_score: 0.8714 - lr: 1.0000e-04
# Epoch 11/60
# 624/624 [==============================] - ETA: 0s - loss: 0.3726 - accuracy: 0.9439 - precision: 0.9551 - recall: 0.9322 - f1_score: 0.9435
# Epoch 11: val_accuracy did not improve from 0.87520
# 624/624 [==============================] - 164s 263ms/step - loss: 0.3726 - accuracy: 0.9439 - precision: 0.9551 - recall: 0.9322 - f1_score: 0.9435 - val_loss: 0.6924 - val_accuracy: 0.8661 - val_precision: 0.8831 - val_recall: 0.8550 - val_f1_score: 0.8688 - lr: 1.0000e-04
# Epoch 12/60
# 624/624 [==============================] - ETA: 0s - loss: 0.3388 - accuracy: 0.9514 - precision: 0.9608 - recall: 0.9414 - f1_score: 0.9510
# Epoch 12: val_accuracy did not improve from 0.87520
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 624/624 [==============================] - 169s 271ms/step - loss: 0.3388 - accuracy: 0.9514 - precision: 0.9608 - recall: 0.9414 - f1_score: 0.9510 - val_loss: 0.7804 - val_accuracy: 0.8545 - val_precision: 0.8665 - val_recall: 0.8484 - val_f1_score: 0.8573 - lr: 1.0000e-04
# Epoch 13/60
# 624/624 [==============================] - ETA: 0s - loss: 0.2101 - accuracy: 0.9760 - precision: 0.9804 - recall: 0.9705 - f1_score: 0.9754
# Epoch 13: val_accuracy improved from 0.87520 to 0.90615, saving model to models\modelo_T_com_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 168s 270ms/step - loss: 0.2101 - accuracy: 0.9760 - precision: 0.9804 - recall: 0.9705 - f1_score: 0.9754 - val_loss: 0.4489 - val_accuracy: 0.9061 - val_precision: 0.9158 - val_recall: 0.8994 - val_f1_score: 0.9075 - lr: 2.0000e-05
# Epoch 14/60
# 624/624 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.9843 - precision: 0.9866 - recall: 0.9814 - f1_score: 0.9840
# Epoch 14: val_accuracy improved from 0.90615 to 0.90905, saving model to models\modelo_T_com_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 166s 267ms/step - loss: 0.1403 - accuracy: 0.9843 - precision: 0.9866 - recall: 0.9814 - f1_score: 0.9840 - val_loss: 0.4565 - val_accuracy: 0.9091 - val_precision: 0.9145 - val_recall: 0.9057 - val_f1_score: 0.9101 - lr: 2.0000e-05
# Epoch 15/60
# 624/624 [==============================] - ETA: 0s - loss: 0.1216 - accuracy: 0.9859 - precision: 0.9877 - recall: 0.9836 - f1_score: 0.9857
# Epoch 15: val_accuracy improved from 0.90905 to 0.90996, saving model to models\modelo_T_com_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 165s 265ms/step - loss: 0.1216 - accuracy: 0.9859 - precision: 0.9877 - recall: 0.9836 - f1_score: 0.9857 - val_loss: 0.4535 - val_accuracy: 0.9100 - val_precision: 0.9159 - val_recall: 0.9076 - val_f1_score: 0.9117 - lr: 2.0000e-05
# Epoch 16/60
# 624/624 [==============================] - ETA: 0s - loss: 0.1034 - accuracy: 0.9892 - precision: 0.9909 - recall: 0.9868 - f1_score: 0.9889
# Epoch 16: val_accuracy did not improve from 0.90996
# 624/624 [==============================] - 166s 266ms/step - loss: 0.1034 - accuracy: 0.9892 - precision: 0.9909 - recall: 0.9868 - f1_score: 0.9889 - val_loss: 0.4729 - val_accuracy: 0.9081 - val_precision: 0.9130 - val_recall: 0.9046 - val_f1_score: 0.9088 - lr: 2.0000e-05
# Epoch 17/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0896 - accuracy: 0.9907 - precision: 0.9920 - recall: 0.9889 - f1_score: 0.9904
# Epoch 17: val_accuracy improved from 0.90996 to 0.91116, saving model to models\modelo_T_com_data_augmentation_rmsprop.keras
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 624/624 [==============================] - 169s 270ms/step - loss: 0.0896 - accuracy: 0.9907 - precision: 0.9920 - recall: 0.9889 - f1_score: 0.9904 - val_loss: 0.4583 - val_accuracy: 0.9112 - val_precision: 0.9156 - val_recall: 0.9079 - val_f1_score: 0.9117 - lr: 2.0000e-05
# Epoch 18/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0808 - accuracy: 0.9918 - precision: 0.9929 - recall: 0.9903 - f1_score: 0.9916
# Epoch 18: val_accuracy improved from 0.91116 to 0.91376, saving model to models\modelo_T_com_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 176s 282ms/step - loss: 0.0808 - accuracy: 0.9918 - precision: 0.9929 - recall: 0.9903 - f1_score: 0.9916 - val_loss: 0.4556 - val_accuracy: 0.9138 - val_precision: 0.9187 - val_recall: 0.9107 - val_f1_score: 0.9146 - lr: 4.0000e-06
# Epoch 19/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0747 - accuracy: 0.9936 - precision: 0.9944 - recall: 0.9920 - f1_score: 0.9932
# Epoch 19: val_accuracy improved from 0.91376 to 0.91476, saving model to models\modelo_T_com_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 172s 276ms/step - loss: 0.0747 - accuracy: 0.9936 - precision: 0.9944 - recall: 0.9920 - f1_score: 0.9932 - val_loss: 0.4567 - val_accuracy: 0.9148 - val_precision: 0.9180 - val_recall: 0.9122 - val_f1_score: 0.9151 - lr: 4.0000e-06
# Epoch 20/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0690 - accuracy: 0.9940 - precision: 0.9951 - recall: 0.9931 - f1_score: 0.9941
# Epoch 20: val_accuracy improved from 0.91476 to 0.91567, saving model to models\modelo_T_com_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 167s 268ms/step - loss: 0.0690 - accuracy: 0.9940 - precision: 0.9951 - recall: 0.9931 - f1_score: 0.9941 - val_loss: 0.4512 - val_accuracy: 0.9157 - val_precision: 0.9202 - val_recall: 0.9132 - val_f1_score: 0.9166 - lr: 4.0000e-06
# Epoch 21/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0640 - accuracy: 0.9945 - precision: 0.9953 - recall: 0.9935 - f1_score: 0.9944
# Epoch 21: val_accuracy improved from 0.91567 to 0.91687, saving model to models\modelo_T_com_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 167s 269ms/step - loss: 0.0640 - accuracy: 0.9945 - precision: 0.9953 - recall: 0.9935 - f1_score: 0.9944 - val_loss: 0.4442 - val_accuracy: 0.9169 - val_precision: 0.9213 - val_recall: 0.9151 - val_f1_score: 0.9182 - lr: 4.0000e-06
# Epoch 22/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0609 - accuracy: 0.9950 - precision: 0.9957 - recall: 0.9940 - f1_score: 0.9948
# Epoch 22: val_accuracy improved from 0.91687 to 0.91727, saving model to models\modelo_T_com_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 166s 266ms/step - loss: 0.0609 - accuracy: 0.9950 - precision: 0.9957 - recall: 0.9940 - f1_score: 0.9948 - val_loss: 0.4430 - val_accuracy: 0.9173 - val_precision: 0.9206 - val_recall: 0.9151 - val_f1_score: 0.9178 - lr: 4.0000e-06
# Epoch 23/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0604 - accuracy: 0.9950 - precision: 0.9960 - recall: 0.9939 - f1_score: 0.9949
# Epoch 23: val_accuracy did not improve from 0.91727
# 624/624 [==============================] - 164s 262ms/step - loss: 0.0604 - accuracy: 0.9950 - precision: 0.9960 - recall: 0.9939 - f1_score: 0.9949 - val_loss: 0.4477 - val_accuracy: 0.9154 - val_precision: 0.9190 - val_recall: 0.9133 - val_f1_score: 0.9161 - lr: 4.0000e-06
# Epoch 24/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0592 - accuracy: 0.9946 - precision: 0.9956 - recall: 0.9936 - f1_score: 0.9946
# Epoch 24: val_accuracy did not improve from 0.91727
# 624/624 [==============================] - 162s 259ms/step - loss: 0.0592 - accuracy: 0.9946 - precision: 0.9956 - recall: 0.9936 - f1_score: 0.9946 - val_loss: 0.4480 - val_accuracy: 0.9162 - val_precision: 0.9202 - val_recall: 0.9147 - val_f1_score: 0.9174 - lr: 4.0000e-06
# Epoch 25/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0589 - accuracy: 0.9949 - precision: 0.9956 - recall: 0.9938 - f1_score: 0.9947
# Epoch 25: val_accuracy did not improve from 0.91727
# 624/624 [==============================] - 164s 263ms/step - loss: 0.0589 - accuracy: 0.9949 - precision: 0.9956 - recall: 0.9938 - f1_score: 0.9947 - val_loss: 0.4556 - val_accuracy: 0.9167 - val_precision: 0.9194 - val_recall: 0.9151 - val_f1_score: 0.9172 - lr: 4.0000e-06
# Epoch 26/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0566 - accuracy: 0.9954 - precision: 0.9962 - recall: 0.9942 - f1_score: 0.9952
# Epoch 26: val_accuracy did not improve from 0.91727
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 624/624 [==============================] - 163s 261ms/step - loss: 0.0566 - accuracy: 0.9954 - precision: 0.9962 - recall: 0.9942 - f1_score: 0.9952 - val_loss: 0.4606 - val_accuracy: 0.9163 - val_precision: 0.9201 - val_recall: 0.9141 - val_f1_score: 0.9170 - lr: 4.0000e-06
# Epoch 27/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0549 - accuracy: 0.9957 - precision: 0.9964 - recall: 0.9951 - f1_score: 0.9957
# Epoch 27: val_accuracy did not improve from 0.91727
# 624/624 [==============================] - 163s 261ms/step - loss: 0.0549 - accuracy: 0.9957 - precision: 0.9964 - recall: 0.9951 - f1_score: 0.9957 - val_loss: 0.4563 - val_accuracy: 0.9170 - val_precision: 0.9196 - val_recall: 0.9148 - val_f1_score: 0.9172 - lr: 8.0000e-07
# Epoch 28/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0504 - accuracy: 0.9966 - precision: 0.9971 - recall: 0.9958 - f1_score: 0.9964
# Epoch 28: val_accuracy did not improve from 0.91727
# 624/624 [==============================] - 163s 261ms/step - loss: 0.0504 - accuracy: 0.9966 - precision: 0.9971 - recall: 0.9958 - f1_score: 0.9964 - val_loss: 0.4570 - val_accuracy: 0.9165 - val_precision: 0.9196 - val_recall: 0.9144 - val_f1_score: 0.9170 - lr: 8.0000e-07
# Epoch 29/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0497 - accuracy: 0.9965 - precision: 0.9970 - recall: 0.9957 - f1_score: 0.9964
# Epoch 29: val_accuracy did not improve from 0.91727
# 624/624 [==============================] - 163s 262ms/step - loss: 0.0497 - accuracy: 0.9965 - precision: 0.9970 - recall: 0.9957 - f1_score: 0.9964 - val_loss: 0.4568 - val_accuracy: 0.9159 - val_precision: 0.9200 - val_recall: 0.9138 - val_f1_score: 0.9169 - lr: 8.0000e-07
# Epoch 30/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0499 - accuracy: 0.9969 - precision: 0.9974 - recall: 0.9959 - f1_score: 0.9967
# Epoch 30: val_accuracy improved from 0.91727 to 0.91737, saving model to models\modelo_T_com_data_augmentation_rmsprop.keras
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# 624/624 [==============================] - 164s 263ms/step - loss: 0.0499 - accuracy: 0.9969 - precision: 0.9974 - recall: 0.9959 - f1_score: 0.9967 - val_loss: 0.4587 - val_accuracy: 0.9174 - val_precision: 0.9204 - val_recall: 0.9152 - val_f1_score: 0.9178 - lr: 8.0000e-07
# Epoch 31/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0525 - accuracy: 0.9962 - precision: 0.9966 - recall: 0.9956 - f1_score: 0.9961
# Epoch 31: val_accuracy did not improve from 0.91737
# 624/624 [==============================] - 167s 267ms/step - loss: 0.0525 - accuracy: 0.9962 - precision: 0.9966 - recall: 0.9956 - f1_score: 0.9961 - val_loss: 0.4601 - val_accuracy: 0.9173 - val_precision: 0.9202 - val_recall: 0.9152 - val_f1_score: 0.9177 - lr: 1.6000e-07
# Epoch 32/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0513 - accuracy: 0.9964 - precision: 0.9970 - recall: 0.9959 - f1_score: 0.9964
# Epoch 32: val_accuracy did not improve from 0.91737
# 624/624 [==============================] - 166s 267ms/step - loss: 0.0513 - accuracy: 0.9964 - precision: 0.9970 - recall: 0.9959 - f1_score: 0.9964 - val_loss: 0.4597 - val_accuracy: 0.9165 - val_precision: 0.9210 - val_recall: 0.9149 - val_f1_score: 0.9179 - lr: 1.6000e-07
# 157/157 [==============================] - 7s 42ms/step - loss: 0.4672 - accuracy: 0.9109 - precision: 0.9147 - recall: 0.9095 - f1_score: 0.9121
# Test Loss: 0.46722596883773804
# Test Accuracy: 0.9108999967575073
# Test Precision: 0.9147138595581055
# Test Recall: 0.909500002861023
# Test F1 Score: 0.9120994210243225

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(history.history['val_precision'], label='val_precision')
plt.plot(history.history['val_recall'], label='val_recall')
plt.plot(history.history['val_f1_score'], label='val_f1_score')
plt.xlabel('Epoch')
plt.ylabel('Metrics')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.title('Validation Precision, Recall, F1 Score')

plt.savefig(f'./plots/modelo_T_com_data_augmentation_rmsprop.png')
plt.tight_layout()
#plt.show()
