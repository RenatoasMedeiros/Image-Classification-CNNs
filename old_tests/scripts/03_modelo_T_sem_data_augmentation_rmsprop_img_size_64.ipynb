# %%
from tensorflow.keras.metrics import Metric
from tensorflow.keras import backend as K
import json
import os
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.regularizers import l2
from tensorflow.keras.mixed_precision import set_global_policy

# %%
# MIX precision training -- facilita no treino!
set_global_policy('mixed_float16')

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# CONSTANTES
BATCH_SIZE = 64
IMG_SIZE = 64
NUM_CLASSES = 10  # nº classes para identificar
NUM_EPOCHS = 60  
LEARNING_RATE = 0.0001  
DENSE_LAYERS = [1024, 512, 256, 128]
DROPOUT_LAYERS = [0.6,0.6,0.6,0.6] # de 0.5 -> 0.6
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 4070, compute capability 8.9

# %%
# Folders do dataset
train_dirs = ['./dataset/train/train1', './dataset/train/train2',
              './dataset/train/train3', './dataset/train/train5']
validation_dir = './dataset/validation'
test_dir = './dataset/test'

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# training generators
train_generators = [train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical') for train_dir in train_dirs]

# Necessário para juntar os trainning generators and repeat


def combined_generator(generators):
    while True:
        for generator in generators:
            for batch in generator:
                yield batch


train_generator = combined_generator(train_generators)

# Validation e test generators
validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical')

# load do modelo ResNet50 - deixar include_top=False 
base_model = ResNet50(weights='imagenet', include_top=False,input_shape=(IMG_SIZE, IMG_SIZE, 3))

# Descongelar camadas (nao meter valores demasiado altos)
for layer in base_model.layers[-50:]:
    layer.trainable = True
# Out:
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.

# %%
class Precision(Metric):
    def __init__(self, name='precision', **kwargs):
        super(Precision, self).__init__(name=name, **kwargs)
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.predicted_positives = self.add_weight(
            name='pp', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = K.round(y_pred)
        y_true = K.cast(y_true, 'float32')
        self.true_positives.assign_add(K.sum(y_true * y_pred))
        self.predicted_positives.assign_add(K.sum(y_pred))

    def result(self):
        return self.true_positives / (self.predicted_positives + K.epsilon())

    def reset_states(self):
        self.true_positives.assign(0)
        self.predicted_positives.assign(0)


class Recall(Metric):
    def __init__(self, name='recall', **kwargs):
        super(Recall, self).__init__(name=name, **kwargs)
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.actual_positives = self.add_weight(name='ap', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = K.round(y_pred)
        y_true = K.cast(y_true, 'float32')
        self.true_positives.assign_add(K.sum(y_true * y_pred))
        self.actual_positives.assign_add(K.sum(y_true))

    def result(self):
        return self.true_positives / (self.actual_positives + K.epsilon())

    def reset_states(self):
        self.true_positives.assign(0)
        self.actual_positives.assign(0)


class F1Score(Metric):
    def __init__(self, name='f1_score', **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.precision = Precision()
        self.recall = Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred)
        self.recall.update_state(y_true, y_pred)

    def result(self):
        precision = self.precision.result()
        recall = self.recall.result()
        return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

    def reset_states(self):
        self.precision.reset_states()
        self.recall.reset_states()

# %%
# Definir as camadas do modelo com parametros ajustados para reduzir o overfitting
model = Sequential([
    base_model,
    BatchNormalization(),
    GlobalAveragePooling2D(),
    # Increase model complexity
    Dense(DENSE_LAYERS[0], activation='relu', kernel_regularizer=l2(0.03)),
    Dropout(DROPOUT_LAYERS[0]),  # High dropout rate for regularization
    BatchNormalization(),
    Dense(DENSE_LAYERS[1], activation='relu', kernel_regularizer=l2(0.03)),
    Dropout(DROPOUT_LAYERS[1]),
    BatchNormalization(),
    Dense(DENSE_LAYERS[2], activation='relu', kernel_regularizer=l2(0.03)),
    Dropout(DROPOUT_LAYERS[2]),
    Dense(DENSE_LAYERS[3], activation='relu', kernel_regularizer=l2(0.03)),
    Dropout(DROPOUT_LAYERS[3]),
    BatchNormalization(),
    Dense(NUM_CLASSES, activation='softmax', dtype='float32')
])

# Compilar o modelo
model.compile(optimizer=RMSprop(learning_rate=LEARNING_RATE),
              loss='categorical_crossentropy',
              metrics=['accuracy', Precision(), Recall(), F1Score()])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2, 2, 2048)        23587712
#
#  batch_normalization (BatchN  (None, 2, 2, 2048)       8192
#  ormalization)
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dropout (Dropout)           (None, 1024)              0
#
#  batch_normalization_1 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  batch_normalization_2 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_4 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 26,391,050
# Trainable params: 26,330,506
# Non-trainable params: 60,544
# _________________________________________________________________

# %%
# CALLBACKS
os.makedirs('logs', exist_ok=True)
checkpoint = ModelCheckpoint(f'models/modelo_T_sem_data_augmentation_rmsprop_img_size_64.keras',
                             monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early_stopping = EarlyStopping(
    monitor='val_loss', patience=10, restore_best_weights=True)  # Increased patience
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=4, min_lr=1e-7, verbose=1)  # More aggressive schedule
csv_logger = CSVLogger(
    f'logs/modelo_T_sem_data_augmentation_rmsprop_img_size_64.csv', separator=',', append=False)

# calcular passos por epoch
steps_per_epoch = sum([gen.samples // BATCH_SIZE for gen in train_generators])
validation_steps = validation_generator.samples // BATCH_SIZE

# %%
# calcular passos por epoch
# Treinar o modelo - Nao tirar os callbacks
history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=NUM_EPOCHS,
    validation_data=validation_generator,
    validation_steps=validation_steps,
    callbacks=[checkpoint, early_stopping, reduce_lr, csv_logger]
)

# Avaliar o modelo no test generator
# Avaliar o modelo no test generator
results = model.evaluate(test_generator)
loss, accuracy, precision, recall, f1_score = results[:5]
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
print(f"Test Precision: {precision}")
print(f"Test Recall: {recall}")
print(f"Test F1 Score: {f1_score}")
# Out:
# Epoch 1/60
# 624/624 [==============================] - ETA: 0s - loss: 53.8645 - accuracy: 0.1720 - precision: 0.2606 - recall: 0.0522 - f1_score: 0.0870
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric Precision implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric Recall implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# Epoch 1: val_accuracy improved from -inf to 0.09826, saving model to models\modelo_T_sem_data_augmentation_rmsprop_img_size_64.keras
# 624/624 [==============================] - 91s 100ms/step - loss: 53.8645 - accuracy: 0.1720 - precision: 0.2606 - recall: 0.0522 - f1_score: 0.0870 - val_loss: 33.1974 - val_accuracy: 0.0983 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - lr: 1.0000e-04
# Epoch 2/60
# 624/624 [==============================] - ETA: 0s - loss: 17.2323 - accuracy: 0.5243 - precision: 0.8239 - recall: 0.3203 - f1_score: 0.4613
# Epoch 2: val_accuracy improved from 0.09826 to 0.71124, saving model to models\modelo_T_sem_data_augmentation_rmsprop_img_size_64.keras
# 624/624 [==============================] - 55s 88ms/step - loss: 17.2323 - accuracy: 0.5243 - precision: 0.8239 - recall: 0.3203 - f1_score: 0.4613 - val_loss: 7.0447 - val_accuracy: 0.7112 - val_precision: 0.9003 - val_recall: 0.4919 - val_f1_score: 0.6362 - lr: 1.0000e-04
# Epoch 3/60
# 624/624 [==============================] - ETA: 0s - loss: 3.6050 - accuracy: 0.8504 - precision: 0.9267 - recall: 0.7336 - f1_score: 0.8190
# Epoch 3: val_accuracy improved from 0.71124 to 0.78425, saving model to models\modelo_T_sem_data_augmentation_rmsprop_img_size_64.keras
# 624/624 [==============================] - 53s 85ms/step - loss: 3.6050 - accuracy: 0.8504 - precision: 0.9267 - recall: 0.7336 - f1_score: 0.8190 - val_loss: 2.0537 - val_accuracy: 0.7843 - val_precision: 0.8359 - val_recall: 0.7436 - val_f1_score: 0.7871 - lr: 1.0000e-04
# Epoch 4/60
# 624/624 [==============================] - ETA: 0s - loss: 0.9522 - accuracy: 0.9505 - precision: 0.9654 - recall: 0.9249 - f1_score: 0.9447
# Epoch 4: val_accuracy improved from 0.78425 to 0.79758, saving model to models\modelo_T_sem_data_augmentation_rmsprop_img_size_64.keras
# 624/624 [==============================] - 55s 87ms/step - loss: 0.9522 - accuracy: 0.9505 - precision: 0.9654 - recall: 0.9249 - f1_score: 0.9447 - val_loss: 1.2087 - val_accuracy: 0.7976 - val_precision: 0.8186 - val_recall: 0.7841 - val_f1_score: 0.8009 - lr: 1.0000e-04
# Epoch 5/60
# 624/624 [==============================] - ETA: 0s - loss: 0.4047 - accuracy: 0.9699 - precision: 0.9760 - recall: 0.9598 - f1_score: 0.9678
# Epoch 5: val_accuracy improved from 0.79758 to 0.81040, saving model to models\modelo_T_sem_data_augmentation_rmsprop_img_size_64.keras
# 624/624 [==============================] - 54s 87ms/step - loss: 0.4047 - accuracy: 0.9699 - precision: 0.9760 - recall: 0.9598 - f1_score: 0.9678 - val_loss: 0.9956 - val_accuracy: 0.8104 - val_precision: 0.8285 - val_recall: 0.7932 - val_f1_score: 0.8105 - lr: 1.0000e-04
# Epoch 6/60
# 624/624 [==============================] - ETA: 0s - loss: 0.2776 - accuracy: 0.9745 - precision: 0.9793 - recall: 0.9680 - f1_score: 0.9736
# Epoch 6: val_accuracy did not improve from 0.81040
# 624/624 [==============================] - 53s 85ms/step - loss: 0.2776 - accuracy: 0.9745 - precision: 0.9793 - recall: 0.9680 - f1_score: 0.9736 - val_loss: 1.1331 - val_accuracy: 0.7987 - val_precision: 0.8125 - val_recall: 0.7902 - val_f1_score: 0.8012 - lr: 1.0000e-04
# Epoch 7/60
# 624/624 [==============================] - ETA: 0s - loss: 0.2249 - accuracy: 0.9805 - precision: 0.9834 - recall: 0.9756 - f1_score: 0.9795
# Epoch 7: val_accuracy improved from 0.81040 to 0.81470, saving model to models\modelo_T_sem_data_augmentation_rmsprop_img_size_64.keras
# 624/624 [==============================] - 57s 91ms/step - loss: 0.2249 - accuracy: 0.9805 - precision: 0.9834 - recall: 0.9756 - f1_score: 0.9795 - val_loss: 1.0818 - val_accuracy: 0.8147 - val_precision: 0.8227 - val_recall: 0.8067 - val_f1_score: 0.8146 - lr: 1.0000e-04
# Epoch 8/60
# 624/624 [==============================] - ETA: 0s - loss: 0.1906 - accuracy: 0.9840 - precision: 0.9862 - recall: 0.9809 - f1_score: 0.9835
# Epoch 8: val_accuracy did not improve from 0.81470
# 624/624 [==============================] - 55s 89ms/step - loss: 0.1906 - accuracy: 0.9840 - precision: 0.9862 - recall: 0.9809 - f1_score: 0.9835 - val_loss: 1.1419 - val_accuracy: 0.8080 - val_precision: 0.8159 - val_recall: 0.8038 - val_f1_score: 0.8098 - lr: 1.0000e-04
# Epoch 9/60
# 624/624 [==============================] - ETA: 0s - loss: 0.1724 - accuracy: 0.9860 - precision: 0.9879 - recall: 0.9828 - f1_score: 0.9853
# Epoch 9: val_accuracy did not improve from 0.81470
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 624/624 [==============================] - 56s 90ms/step - loss: 0.1724 - accuracy: 0.9860 - precision: 0.9879 - recall: 0.9828 - f1_score: 0.9853 - val_loss: 1.2321 - val_accuracy: 0.7990 - val_precision: 0.8055 - val_recall: 0.7950 - val_f1_score: 0.8002 - lr: 1.0000e-04
# Epoch 10/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0898 - accuracy: 0.9959 - precision: 0.9965 - recall: 0.9944 - f1_score: 0.9955
# Epoch 10: val_accuracy improved from 0.81470 to 0.83774, saving model to models\modelo_T_sem_data_augmentation_rmsprop_img_size_64.keras
# 624/624 [==============================] - 56s 90ms/step - loss: 0.0898 - accuracy: 0.9959 - precision: 0.9965 - recall: 0.9944 - f1_score: 0.9955 - val_loss: 0.9372 - val_accuracy: 0.8377 - val_precision: 0.8438 - val_recall: 0.8340 - val_f1_score: 0.8389 - lr: 2.0000e-05
# Epoch 11/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9984 - precision: 0.9986 - recall: 0.9973 - f1_score: 0.9979
# Epoch 11: val_accuracy improved from 0.83774 to 0.84125, saving model to models\modelo_T_sem_data_augmentation_rmsprop_img_size_64.keras
# 624/624 [==============================] - 56s 89ms/step - loss: 0.0546 - accuracy: 0.9984 - precision: 0.9986 - recall: 0.9973 - f1_score: 0.9979 - val_loss: 1.0936 - val_accuracy: 0.8412 - val_precision: 0.8441 - val_recall: 0.8400 - val_f1_score: 0.8421 - lr: 2.0000e-05
# Epoch 12/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0478 - accuracy: 0.9987 - precision: 0.9990 - recall: 0.9978 - f1_score: 0.9984
# Epoch 12: val_accuracy did not improve from 0.84125
# 624/624 [==============================] - 55s 89ms/step - loss: 0.0478 - accuracy: 0.9987 - precision: 0.9990 - recall: 0.9978 - f1_score: 0.9984 - val_loss: 1.1658 - val_accuracy: 0.8363 - val_precision: 0.8385 - val_recall: 0.8356 - val_f1_score: 0.8371 - lr: 2.0000e-05
# Epoch 13/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0417 - accuracy: 0.9992 - precision: 0.9994 - recall: 0.9984 - f1_score: 0.9989
# Epoch 13: val_accuracy improved from 0.84125 to 0.84305, saving model to models\modelo_T_sem_data_augmentation_rmsprop_img_size_64.keras
# 624/624 [==============================] - 57s 92ms/step - loss: 0.0417 - accuracy: 0.9992 - precision: 0.9994 - recall: 0.9984 - f1_score: 0.9989 - val_loss: 1.1783 - val_accuracy: 0.8430 - val_precision: 0.8443 - val_recall: 0.8421 - val_f1_score: 0.8432 - lr: 2.0000e-05
# Epoch 14/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0396 - accuracy: 0.9993 - precision: 0.9994 - recall: 0.9988 - f1_score: 0.9991
# Epoch 14: val_accuracy did not improve from 0.84305
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 624/624 [==============================] - 55s 88ms/step - loss: 0.0396 - accuracy: 0.9993 - precision: 0.9994 - recall: 0.9988 - f1_score: 0.9991 - val_loss: 1.2187 - val_accuracy: 0.8412 - val_precision: 0.8432 - val_recall: 0.8408 - val_f1_score: 0.8420 - lr: 2.0000e-05
# Epoch 15/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0359 - accuracy: 0.9994 - precision: 0.9996 - recall: 0.9991 - f1_score: 0.9993
# Epoch 15: val_accuracy improved from 0.84305 to 0.84585, saving model to models\modelo_T_sem_data_augmentation_rmsprop_img_size_64.keras
# 624/624 [==============================] - 56s 90ms/step - loss: 0.0359 - accuracy: 0.9994 - precision: 0.9996 - recall: 0.9991 - f1_score: 0.9993 - val_loss: 1.2198 - val_accuracy: 0.8459 - val_precision: 0.8471 - val_recall: 0.8448 - val_f1_score: 0.8459 - lr: 4.0000e-06
# Epoch 16/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0334 - accuracy: 0.9998 - precision: 0.9998 - recall: 0.9995 - f1_score: 0.9997
# Epoch 16: val_accuracy did not improve from 0.84585
# 624/624 [==============================] - 55s 88ms/step - loss: 0.0334 - accuracy: 0.9998 - precision: 0.9998 - recall: 0.9995 - f1_score: 0.9997 - val_loss: 1.2356 - val_accuracy: 0.8436 - val_precision: 0.8453 - val_recall: 0.8436 - val_f1_score: 0.8445 - lr: 4.0000e-06
# Epoch 17/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0328 - accuracy: 0.9996 - precision: 0.9997 - recall: 0.9992 - f1_score: 0.9995
# Epoch 17: val_accuracy improved from 0.84585 to 0.84615, saving model to models\modelo_T_sem_data_augmentation_rmsprop_img_size_64.keras
# 624/624 [==============================] - 56s 90ms/step - loss: 0.0328 - accuracy: 0.9996 - precision: 0.9997 - recall: 0.9992 - f1_score: 0.9995 - val_loss: 1.2328 - val_accuracy: 0.8462 - val_precision: 0.8473 - val_recall: 0.8456 - val_f1_score: 0.8464 - lr: 4.0000e-06
# Epoch 18/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0336 - accuracy: 0.9995 - precision: 0.9997 - recall: 0.9993 - f1_score: 0.9995
# Epoch 18: val_accuracy did not improve from 0.84615
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 624/624 [==============================] - 56s 89ms/step - loss: 0.0336 - accuracy: 0.9995 - precision: 0.9997 - recall: 0.9993 - f1_score: 0.9995 - val_loss: 1.2544 - val_accuracy: 0.8460 - val_precision: 0.8472 - val_recall: 0.8455 - val_f1_score: 0.8463 - lr: 4.0000e-06
# Epoch 19/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9997 - precision: 0.9999 - recall: 0.9994 - f1_score: 0.9997
# Epoch 19: val_accuracy improved from 0.84615 to 0.84716, saving model to models\modelo_T_sem_data_augmentation_rmsprop_img_size_64.keras
# 624/624 [==============================] - 57s 91ms/step - loss: 0.0319 - accuracy: 0.9997 - precision: 0.9999 - recall: 0.9994 - f1_score: 0.9997 - val_loss: 1.2499 - val_accuracy: 0.8472 - val_precision: 0.8483 - val_recall: 0.8467 - val_f1_score: 0.8475 - lr: 8.0000e-07
# Epoch 20/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0315 - accuracy: 0.9997 - precision: 0.9998 - recall: 0.9996 - f1_score: 0.9997
# Epoch 20: val_accuracy improved from 0.84716 to 0.84736, saving model to models\modelo_T_sem_data_augmentation_rmsprop_img_size_64.keras
# 624/624 [==============================] - 55s 89ms/step - loss: 0.0315 - accuracy: 0.9997 - precision: 0.9998 - recall: 0.9996 - f1_score: 0.9997 - val_loss: 1.2472 - val_accuracy: 0.8474 - val_precision: 0.8487 - val_recall: 0.8469 - val_f1_score: 0.8478 - lr: 8.0000e-07
# 157/157 [==============================] - 8s 51ms/step - loss: 0.9356 - accuracy: 0.8384 - precision: 0.8427 - recall: 0.8341 - f1_score: 0.8384
# Test Loss: 0.9356486201286316
# Test Accuracy: 0.8384000062942505
# Test Precision: 0.8426954746246338
# Test Recall: 0.8341000080108643
# Test F1 Score: 0.8383756279945374

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(history.history['val_precision'], label='val_precision')
plt.plot(history.history['val_recall'], label='val_recall')
plt.plot(history.history['val_f1_score'], label='val_f1_score')
plt.xlabel('Epoch')
plt.ylabel('Metrics')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.title('Validation Precision, Recall, F1 Score')

plt.savefig(f'./plots/modelo_T_sem_data_augmentation_rmsprop_img_size_64.png')
plt.tight_layout()
# plt.show()
