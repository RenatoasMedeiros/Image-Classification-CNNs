# %%
from tensorflow.keras.metrics import Metric
from tensorflow.keras import backend as K
import json
import os
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.regularizers import l2
from tensorflow.keras.mixed_precision import set_global_policy

# %%
# Enable mixed precision training
set_global_policy('mixed_float16')

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# CONSTANTES
BATCH_SIZE = 64
IMG_SIZE = 150
NUM_CLASSES = 10  # nº classes para identificar
NUM_EPOCHS = 60  # Further increase number of epochs
LEARNING_RATE = 0.0001  # Slightly higher learning rate
DENSE_LAYERS = [1024, 512, 256, 128]
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 4070, compute capability 8.9

# %%
# Define directories
train_dirs = ['./dataset/train/train1', './dataset/train/train2',
              './dataset/train/train3', './dataset/train/train5']
validation_dir = './dataset/validation'
test_dir = './dataset/test'

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# training generators
train_generators = [train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical') for train_dir in train_dirs]

# Necessário para junstar os trainning generators and repeat


def combined_generator(generators):
    while True:
        for generator in generators:
            for batch in generator:
                yield batch


train_generator = combined_generator(train_generators)

# Validation e test generators
validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical')

# Load the pre-trained ResNet50 model without the top layer and adjust input shape
base_model = ResNet50(weights='imagenet', include_top=False,
                      input_shape=(IMG_SIZE, IMG_SIZE, 3))

# Unfreeze some top layers of the base model
for layer in base_model.layers[-50:]:
    layer.trainable = True
# Out:
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.

# %%
class Precision(Metric):
    def __init__(self, name='precision', **kwargs):
        super(Precision, self).__init__(name=name, **kwargs)
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.predicted_positives = self.add_weight(
            name='pp', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = K.round(y_pred)
        y_true = K.cast(y_true, 'float32')
        self.true_positives.assign_add(K.sum(y_true * y_pred))
        self.predicted_positives.assign_add(K.sum(y_pred))

    def result(self):
        return self.true_positives / (self.predicted_positives + K.epsilon())

    def reset_states(self):
        self.true_positives.assign(0)
        self.predicted_positives.assign(0)


class Recall(Metric):
    def __init__(self, name='recall', **kwargs):
        super(Recall, self).__init__(name=name, **kwargs)
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.actual_positives = self.add_weight(name='ap', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = K.round(y_pred)
        y_true = K.cast(y_true, 'float32')
        self.true_positives.assign_add(K.sum(y_true * y_pred))
        self.actual_positives.assign_add(K.sum(y_true))

    def result(self):
        return self.true_positives / (self.actual_positives + K.epsilon())

    def reset_states(self):
        self.true_positives.assign(0)
        self.actual_positives.assign(0)


class F1Score(Metric):
    def __init__(self, name='f1_score', **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.precision = Precision()
        self.recall = Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred)
        self.recall.update_state(y_true, y_pred)

    def result(self):
        precision = self.precision.result()
        recall = self.recall.result()
        return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

    def reset_states(self):
        self.precision.reset_states()
        self.recall.reset_states()

# %%
# Define the model with adjusted parameters to reduce overfitting
model = Sequential([
    base_model,
    BatchNormalization(),
    GlobalAveragePooling2D(),
    # Increase model complexity
    Dense(DENSE_LAYERS[0], activation='relu', kernel_regularizer=l2(0.03)),
    Dropout(0.5),  # High dropout rate for regularization
    BatchNormalization(),
    Dense(DENSE_LAYERS[1], activation='relu', kernel_regularizer=l2(0.03)),
    Dropout(0.5),
    BatchNormalization(),
    Dense(DENSE_LAYERS[2], activation='relu', kernel_regularizer=l2(0.03)),
    Dropout(0.5),
    Dense(DENSE_LAYERS[3], activation='relu', kernel_regularizer=l2(0.03)),
    Dropout(0.5),
    BatchNormalization(),
    Dense(NUM_CLASSES, activation='softmax', dtype='float32')
])

# Compile the model
model.compile(optimizer=RMSprop(learning_rate=LEARNING_RATE),
              loss='categorical_crossentropy',
              metrics=['accuracy', Precision(), Recall(), F1Score()])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 5, 5, 2048)        23587712
#
#  batch_normalization (BatchN  (None, 5, 5, 2048)       8192
#  ormalization)
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dropout (Dropout)           (None, 1024)              0
#
#  batch_normalization_1 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  batch_normalization_2 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_4 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 26,391,050
# Trainable params: 26,330,506
# Non-trainable params: 60,544
# _________________________________________________________________

# %%
# Define callbacks
os.makedirs('logs', exist_ok=True)
checkpoint = ModelCheckpoint(f'models/modelo_T_sem_data_augmentation_rmsprop.keras',
                             monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early_stopping = EarlyStopping(
    monitor='val_loss', patience=10, restore_best_weights=True)  # Increased patience
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=4, min_lr=1e-7, verbose=1)  # More aggressive schedule
csv_logger = CSVLogger(
    f'logs/modelo_T_sem_data_augmentation_rmsprop.csv', separator=',', append=False)

# Calculate steps per epoch
steps_per_epoch = sum([gen.samples // BATCH_SIZE for gen in train_generators])
validation_steps = validation_generator.samples // BATCH_SIZE

# %%
# Calculate steps per epoch
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=NUM_EPOCHS,
    validation_data=validation_generator,
    validation_steps=validation_steps,
    callbacks=[checkpoint, early_stopping, reduce_lr, csv_logger]
)

# Evaluate the model
# Evaluate the model
results = model.evaluate(test_generator)
loss, accuracy, precision, recall, f1_score = results[:5]
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
print(f"Test Precision: {precision}")
print(f"Test Recall: {recall}")
print(f"Test F1 Score: {f1_score}")
# Out:
# Epoch 1/60
# 624/624 [==============================] - ETA: 0s - loss: 47.5384 - accuracy: 0.4897 - precision: 0.7504 - recall: 0.3231 - f1_score: 0.4517
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric Precision implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric Recall implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# c:\Users\USER\.conda\envs\py310\lib\site-packages\keras\engine\training.py:2319: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# Epoch 1: val_accuracy improved from -inf to 0.20393, saving model to models\modelo_T_sem_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 102s 129ms/step - loss: 47.5384 - accuracy: 0.4897 - precision: 0.7504 - recall: 0.3231 - f1_score: 0.4517 - val_loss: 19.3776 - val_accuracy: 0.2039 - val_precision: 0.2929 - val_recall: 0.1003 - val_f1_score: 0.1494 - lr: 1.0000e-04
# Epoch 2/60
# 624/624 [==============================] - ETA: 0s - loss: 6.8192 - accuracy: 0.9332 - precision: 0.9594 - recall: 0.8888 - f1_score: 0.9228
# Epoch 2: val_accuracy improved from 0.20393 to 0.83494, saving model to models\modelo_T_sem_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 77s 123ms/step - loss: 6.8192 - accuracy: 0.9332 - precision: 0.9594 - recall: 0.8888 - f1_score: 0.9228 - val_loss: 2.2940 - val_accuracy: 0.8349 - val_precision: 0.8789 - val_recall: 0.7976 - val_f1_score: 0.8363 - lr: 1.0000e-04
# Epoch 3/60
# 624/624 [==============================] - ETA: 0s - loss: 0.9245 - accuracy: 0.9718 - precision: 0.9778 - recall: 0.9626 - f1_score: 0.9701
# Epoch 3: val_accuracy improved from 0.83494 to 0.84024, saving model to models\modelo_T_sem_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 78s 125ms/step - loss: 0.9245 - accuracy: 0.9718 - precision: 0.9778 - recall: 0.9626 - f1_score: 0.9701 - val_loss: 0.9578 - val_accuracy: 0.8402 - val_precision: 0.8641 - val_recall: 0.8225 - val_f1_score: 0.8428 - lr: 1.0000e-04
# Epoch 4/60
# 624/624 [==============================] - ETA: 0s - loss: 0.3226 - accuracy: 0.9773 - precision: 0.9810 - recall: 0.9721 - f1_score: 0.9765
# Epoch 4: val_accuracy improved from 0.84024 to 0.85066, saving model to models\modelo_T_sem_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 78s 125ms/step - loss: 0.3226 - accuracy: 0.9773 - precision: 0.9810 - recall: 0.9721 - f1_score: 0.9765 - val_loss: 0.8320 - val_accuracy: 0.8507 - val_precision: 0.8632 - val_recall: 0.8440 - val_f1_score: 0.8535 - lr: 1.0000e-04
# Epoch 5/60
# 624/624 [==============================] - ETA: 0s - loss: 0.2104 - accuracy: 0.9820 - precision: 0.9847 - recall: 0.9785 - f1_score: 0.9816
# Epoch 5: val_accuracy improved from 0.85066 to 0.86008, saving model to models\modelo_T_sem_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 79s 127ms/step - loss: 0.2104 - accuracy: 0.9820 - precision: 0.9847 - recall: 0.9785 - f1_score: 0.9816 - val_loss: 0.8145 - val_accuracy: 0.8601 - val_precision: 0.8714 - val_recall: 0.8535 - val_f1_score: 0.8623 - lr: 1.0000e-04
# Epoch 6/60
# 624/624 [==============================] - ETA: 0s - loss: 0.1823 - accuracy: 0.9821 - precision: 0.9851 - recall: 0.9792 - f1_score: 0.9821
# Epoch 6: val_accuracy did not improve from 0.86008
# 624/624 [==============================] - 78s 125ms/step - loss: 0.1823 - accuracy: 0.9821 - precision: 0.9851 - recall: 0.9792 - f1_score: 0.9821 - val_loss: 0.8523 - val_accuracy: 0.8519 - val_precision: 0.8635 - val_recall: 0.8430 - val_f1_score: 0.8532 - lr: 1.0000e-04
# Epoch 7/60
# 624/624 [==============================] - ETA: 0s - loss: 0.1576 - accuracy: 0.9854 - precision: 0.9876 - recall: 0.9832 - f1_score: 0.9854
# Epoch 7: val_accuracy improved from 0.86008 to 0.87610, saving model to models\modelo_T_sem_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 78s 124ms/step - loss: 0.1576 - accuracy: 0.9854 - precision: 0.9876 - recall: 0.9832 - f1_score: 0.9854 - val_loss: 0.7327 - val_accuracy: 0.8761 - val_precision: 0.8871 - val_recall: 0.8701 - val_f1_score: 0.8785 - lr: 1.0000e-04
# Epoch 8/60
# 624/624 [==============================] - ETA: 0s - loss: 0.1450 - accuracy: 0.9875 - precision: 0.9893 - recall: 0.9851 - f1_score: 0.9872
# Epoch 8: val_accuracy did not improve from 0.87610
# 624/624 [==============================] - 77s 123ms/step - loss: 0.1450 - accuracy: 0.9875 - precision: 0.9893 - recall: 0.9851 - f1_score: 0.9872 - val_loss: 0.7906 - val_accuracy: 0.8656 - val_precision: 0.8774 - val_recall: 0.8591 - val_f1_score: 0.8682 - lr: 1.0000e-04
# Epoch 9/60
# 624/624 [==============================] - ETA: 0s - loss: 0.1327 - accuracy: 0.9887 - precision: 0.9903 - recall: 0.9867 - f1_score: 0.9885
# Epoch 9: val_accuracy did not improve from 0.87610
# 624/624 [==============================] - 77s 124ms/step - loss: 0.1327 - accuracy: 0.9887 - precision: 0.9903 - recall: 0.9867 - f1_score: 0.9885 - val_loss: 0.8673 - val_accuracy: 0.8641 - val_precision: 0.8723 - val_recall: 0.8591 - val_f1_score: 0.8656 - lr: 1.0000e-04
# Epoch 10/60
# 624/624 [==============================] - ETA: 0s - loss: 0.1217 - accuracy: 0.9902 - precision: 0.9916 - recall: 0.9883 - f1_score: 0.9900
# Epoch 10: val_accuracy did not improve from 0.87610
# 624/624 [==============================] - 77s 124ms/step - loss: 0.1217 - accuracy: 0.9902 - precision: 0.9916 - recall: 0.9883 - f1_score: 0.9900 - val_loss: 0.8190 - val_accuracy: 0.8700 - val_precision: 0.8791 - val_recall: 0.8646 - val_f1_score: 0.8718 - lr: 1.0000e-04
# Epoch 11/60
# 624/624 [==============================] - ETA: 0s - loss: 0.1191 - accuracy: 0.9897 - precision: 0.9912 - recall: 0.9881 - f1_score: 0.9897
# Epoch 11: val_accuracy did not improve from 0.87610
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 624/624 [==============================] - 78s 125ms/step - loss: 0.1191 - accuracy: 0.9897 - precision: 0.9912 - recall: 0.9881 - f1_score: 0.9897 - val_loss: 0.9835 - val_accuracy: 0.8655 - val_precision: 0.8704 - val_recall: 0.8627 - val_f1_score: 0.8665 - lr: 1.0000e-04
# Epoch 12/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9981 - precision: 0.9984 - recall: 0.9975 - f1_score: 0.9979
# Epoch 12: val_accuracy improved from 0.87610 to 0.89623, saving model to models\modelo_T_sem_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 79s 126ms/step - loss: 0.0519 - accuracy: 0.9981 - precision: 0.9984 - recall: 0.9975 - f1_score: 0.9979 - val_loss: 0.6098 - val_accuracy: 0.8962 - val_precision: 0.9023 - val_recall: 0.8921 - val_f1_score: 0.8972 - lr: 2.0000e-05
# Epoch 13/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9995 - precision: 0.9995 - recall: 0.9992 - f1_score: 0.9993
# Epoch 13: val_accuracy improved from 0.89623 to 0.89924, saving model to models\modelo_T_sem_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 76s 122ms/step - loss: 0.0290 - accuracy: 0.9995 - precision: 0.9995 - recall: 0.9992 - f1_score: 0.9993 - val_loss: 0.6601 - val_accuracy: 0.8992 - val_precision: 0.9031 - val_recall: 0.8975 - val_f1_score: 0.9003 - lr: 2.0000e-05
# Epoch 14/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9995 - precision: 0.9996 - recall: 0.9993 - f1_score: 0.9995
# Epoch 14: val_accuracy improved from 0.89924 to 0.90335, saving model to models\modelo_T_sem_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 77s 123ms/step - loss: 0.0265 - accuracy: 0.9995 - precision: 0.9996 - recall: 0.9993 - f1_score: 0.9995 - val_loss: 0.6847 - val_accuracy: 0.9033 - val_precision: 0.9061 - val_recall: 0.9014 - val_f1_score: 0.9038 - lr: 2.0000e-05
# Epoch 15/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9996 - precision: 0.9997 - recall: 0.9993 - f1_score: 0.9995
# Epoch 15: val_accuracy improved from 0.90335 to 0.90385, saving model to models\modelo_T_sem_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 76s 122ms/step - loss: 0.0239 - accuracy: 0.9996 - precision: 0.9997 - recall: 0.9993 - f1_score: 0.9995 - val_loss: 0.6503 - val_accuracy: 0.9038 - val_precision: 0.9069 - val_recall: 0.9024 - val_f1_score: 0.9047 - lr: 2.0000e-05
# Epoch 16/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0226 - accuracy: 0.9996 - precision: 0.9997 - recall: 0.9994 - f1_score: 0.9995
# Epoch 16: val_accuracy did not improve from 0.90385
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 624/624 [==============================] - 75s 121ms/step - loss: 0.0226 - accuracy: 0.9996 - precision: 0.9997 - recall: 0.9994 - f1_score: 0.9995 - val_loss: 0.6972 - val_accuracy: 0.9021 - val_precision: 0.9044 - val_recall: 0.9004 - val_f1_score: 0.9024 - lr: 2.0000e-05
# Epoch 17/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9997 - precision: 0.9998 - recall: 0.9995 - f1_score: 0.9997
# Epoch 17: val_accuracy improved from 0.90385 to 0.90515, saving model to models\modelo_T_sem_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 75s 121ms/step - loss: 0.0213 - accuracy: 0.9997 - precision: 0.9998 - recall: 0.9995 - f1_score: 0.9997 - val_loss: 0.6666 - val_accuracy: 0.9051 - val_precision: 0.9073 - val_recall: 0.9038 - val_f1_score: 0.9056 - lr: 4.0000e-06
# Epoch 18/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9999 - precision: 0.9999 - recall: 0.9999 - f1_score: 0.9999
# Epoch 18: val_accuracy improved from 0.90515 to 0.90695, saving model to models\modelo_T_sem_data_augmentation_rmsprop.keras
# 624/624 [==============================] - 76s 122ms/step - loss: 0.0192 - accuracy: 0.9999 - precision: 0.9999 - recall: 0.9999 - f1_score: 0.9999 - val_loss: 0.6688 - val_accuracy: 0.9070 - val_precision: 0.9085 - val_recall: 0.9057 - val_f1_score: 0.9071 - lr: 4.0000e-06
# Epoch 19/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9999 - precision: 0.9999 - recall: 0.9999 - f1_score: 0.9999
# Epoch 19: val_accuracy did not improve from 0.90695
# 624/624 [==============================] - 75s 120ms/step - loss: 0.0191 - accuracy: 0.9999 - precision: 0.9999 - recall: 0.9999 - f1_score: 0.9999 - val_loss: 0.6580 - val_accuracy: 0.9069 - val_precision: 0.9094 - val_recall: 0.9055 - val_f1_score: 0.9075 - lr: 4.0000e-06
# Epoch 20/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9999 - precision: 1.0000 - recall: 0.9999 - f1_score: 0.9999
# Epoch 20: val_accuracy did not improve from 0.90695
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 624/624 [==============================] - 76s 121ms/step - loss: 0.0186 - accuracy: 0.9999 - precision: 1.0000 - recall: 0.9999 - f1_score: 0.9999 - val_loss: 0.6626 - val_accuracy: 0.9062 - val_precision: 0.9082 - val_recall: 0.9049 - val_f1_score: 0.9066 - lr: 4.0000e-06
# Epoch 21/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9998 - precision: 0.9998 - recall: 0.9998 - f1_score: 0.9998
# Epoch 21: val_accuracy did not improve from 0.90695
# 624/624 [==============================] - 76s 122ms/step - loss: 0.0188 - accuracy: 0.9998 - precision: 0.9998 - recall: 0.9998 - f1_score: 0.9998 - val_loss: 0.6678 - val_accuracy: 0.9058 - val_precision: 0.9082 - val_recall: 0.9046 - val_f1_score: 0.9064 - lr: 8.0000e-07
# Epoch 22/60
# 624/624 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9999 - f1_score: 0.9999
# Epoch 22: val_accuracy did not improve from 0.90695
# 624/624 [==============================] - 80s 128ms/step - loss: 0.0181 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9999 - f1_score: 0.9999 - val_loss: 0.6682 - val_accuracy: 0.9058 - val_precision: 0.9082 - val_recall: 0.9045 - val_f1_score: 0.9064 - lr: 8.0000e-07
# 157/157 [==============================] - 9s 56ms/step - loss: 0.6096 - accuracy: 0.8967 - precision: 0.9023 - recall: 0.8929 - f1_score: 0.8976
# Test Loss: 0.6096206307411194
# Test Accuracy: 0.8967000246047974
# Test Precision: 0.9022837281227112
# Test Recall: 0.8928999900817871
# Test F1 Score: 0.8975672721862793

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(history.history['val_precision'], label='val_precision')
plt.plot(history.history['val_recall'], label='val_recall')
plt.plot(history.history['val_f1_score'], label='val_f1_score')
plt.xlabel('Epoch')
plt.ylabel('Metrics')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.title('Validation Precision, Recall, F1 Score')

plt.savefig(f'./plots/modelo_T_sem_data_augmentation_rmsprop.png')
plt.tight_layout()
# plt.show()
